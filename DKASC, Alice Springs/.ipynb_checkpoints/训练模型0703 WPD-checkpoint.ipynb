# %% [markdown]
# # DKASC_Alice多模型训练0703 小波包分解

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import tensorflow as tf
import keras
import catboost as cb
from pandas import read_csv
from math import sqrt
from numpy import concatenate
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn import svm
from keras.layers.core import Dense, Activation, Dropout
from sklearn.externals import joblib
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:469: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:470: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:471: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:472: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:473: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:476: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
config = tf.ConfigProto(allow_soft_placement = True)
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction = 0.5)
config.gpu_options.allow_growth = True
sess0 = tf.InteractiveSession(config = config)

# %%
print(os.getcwd()) # 打印当前工作目录
# Out:
# E:\Research Project\DKASC, Alice Springs

# %%
os.listdir(os.getcwd())
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  '101-Site_DKA-WeatherStation',
#  '96-Site_DKA-MasterMeter1',
#  'Alice_Springs_2016-2020',
#  'Dataset',
#  'logs',
#  'picture',
#  'Predict',
#  'Program backups',
#  'temp',
#  'venv',
#  '数据集_小波包分解重构数据.ipynb',
#  '数据集_预处理_第二版0702.ipynb',
#  '测试小波分解.ipynb',
#  '测试模型0622.ipynb',
#  '画图.ipynb',
#  '笔记.ipynb',
#  '训练模型0622.ipynb',
#  '训练模型0702.ipynb',
#  '训练模型0703 WPD.ipynb']

# %%
os.chdir("./Dataset")

# %%
os.listdir()
# Out:
# ['DKA.Station_1-9.csv',
#  'NaN_DKA.Station.csv',
#  'raw_DKA.Station_1-9.csv',
#  'test',
#  'test0702',
#  'testdata.csv',
#  'testWPD',
#  'test_1A.csv',
#  'train',
#  'train0702',
#  'traindata.csv',
#  'trainWPD',
#  'train_1A.csv',
#  '测试集8个站点.csv',
#  '训练集8个站点.csv']

# %%
train = pd.read_csv('./trainWPD/WPD_train_Station_4.csv')
test = pd.read_csv('./testWPD/WPD_test_Station_4.csv')

# %%
#查看输入数据维度
print(train.shape)
print(test.shape)
# Out:
# (314843, 15)
# (102888, 15)

# %%
train.head(5)
# Out:
#        Timestamp  Year  Month  Day  Hour  Minutes  Temperature(°C)  \
# 0  2016/1/1 0:00  2016      1    1     0        0        17.176111
# 1  2016/1/1 0:05  2016      1    1     0        5        17.133446
# 2  2016/1/1 0:10  2016      1    1     0       10        17.084999
# 3  2016/1/1 0:15  2016      1    1     0       15        16.955778
# 4  2016/1/1 0:20  2016      1    1     0       20        16.854271
#
#    Relative Humidity(%)  Wind Direction(Degrees)  Daily Rainfall(mm)  \
# 0             87.095665               186.941284                 0.0
# 1             87.671669               191.876770                 0.0
# 2             88.563240               188.268082                 0.0
# 3             90.001663               197.727295                 0.0
# 4             91.222733               193.704559                 0.0
#
#    Global Horizontal Radiation(W/m²)  Diffuse Horizontal Radiation(W/m²)  \
# 0                           2.672255                            1.103375
# 1                           2.703700                            1.152340
# 2                           3.013785                            1.566642
# 3                           3.421924                            1.707677
# 4                           3.292158                            1.746989
#
#           A         D  Station_4
# 0  0.000421 -0.000021   0.000400
# 1  0.000479 -0.000079   0.000400
# 2  0.000391  0.000142   0.000533
# 3  0.000256 -0.000190   0.000067
# 4  0.000396  0.000204   0.000600

# %%
test.head(5)
# Out:
#        Timestamp  Year  Month  Day  Hour  Minutes  Temperature(°C)  \
# 0  2019/1/1 0:00  2019      1    1     0        0        30.020723
# 1  2019/1/1 0:05  2019      1    1     0        5        29.958653
# 2  2019/1/1 0:10  2019      1    1     0       10        29.884491
# 3  2019/1/1 0:15  2019      1    1     0       15        29.831554
# 4  2019/1/1 0:20  2019      1    1     0       20        29.750330
#
#    Relative Humidity(%)  Wind Direction(Degrees)  Daily Rainfall(mm)  \
# 0             20.125513                32.213470                 0.0
# 1             20.040049                32.158791                 0.0
# 2             20.013313                32.155808                 0.0
# 3             20.068233                32.178555                 0.0
# 4             20.086567                32.166214                 0.0
#
#    Global Horizontal Radiation(W/m²)  Diffuse Horizontal Radiation(W/m²)  \
# 0                           1.543787                            1.349848
# 1                           1.373370                            1.244123
# 2                           1.142953                            0.992849
# 3                           0.709036                            0.611533
# 4                           1.058623                            0.814599
#
#           A         D  Station_4
# 0  0.000500  0.000033   0.000533
# 1  0.000575 -0.000141   0.000433
# 2  0.000654  0.000213   0.000867
# 3  0.000776 -0.000009   0.000767
# 4  0.000650 -0.000117   0.000533

# %% [markdown]
# # 数据预处理训练集去异常值

# %%
#使用df.isnull().sum()来获得与行数None和NaN值。
train.isnull().sum()
# Out:
# Timestamp                             0
# Year                                  0
# Month                                 0
# Day                                   0
# Hour                                  0
# Minutes                               0
# Temperature(°C)                       0
# Relative Humidity(%)                  0
# Wind Direction(Degrees)               0
# Daily Rainfall(mm)                    0
# Global Horizontal Radiation(W/m²)     0
# Diffuse Horizontal Radiation(W/m²)    0
# A                                     0
# D                                     0
# Station_4                             0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Timestamp                             0
# Year                                  0
# Month                                 0
# Day                                   0
# Hour                                  0
# Minutes                               0
# Temperature(°C)                       0
# Relative Humidity(%)                  0
# Wind Direction(Degrees)               0
# Daily Rainfall(mm)                    0
# Global Horizontal Radiation(W/m²)     0
# Diffuse Horizontal Radiation(W/m²)    0
# A                                     0
# D                                     0
# Station_4                             0
# dtype: int64

# %%
train.columns
# Out:
# Index(['Timestamp', 'Year', 'Month', 'Day', 'Hour', 'Minutes',
#        'Temperature(°C)', 'Relative Humidity(%)', 'Wind Direction(Degrees)',
#        'Daily Rainfall(mm)', 'Global Horizontal Radiation(W/m²)',
#        'Diffuse Horizontal Radiation(W/m²)', 'A', 'D', 'Station_4'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Timestamp', 'Year', 'Month', 'Day', 'Hour', 'Minutes',
#        'Temperature(°C)', 'Relative Humidity(%)', 'Wind Direction(Degrees)',
#        'Daily Rainfall(mm)', 'Global Horizontal Radiation(W/m²)',
#        'Diffuse Horizontal Radiation(W/m²)', 'A', 'D', 'Station_4'],
#       dtype='object')

# %%
train.head()
# Out:
#        Timestamp  Year  Month  Day  Hour  Minutes  Temperature(°C)  \
# 0  2016/1/1 0:00  2016      1    1     0        0        17.176111
# 1  2016/1/1 0:05  2016      1    1     0        5        17.133446
# 2  2016/1/1 0:10  2016      1    1     0       10        17.084999
# 3  2016/1/1 0:15  2016      1    1     0       15        16.955778
# 4  2016/1/1 0:20  2016      1    1     0       20        16.854271
#
#    Relative Humidity(%)  Wind Direction(Degrees)  Daily Rainfall(mm)  \
# 0             87.095665               186.941284                 0.0
# 1             87.671669               191.876770                 0.0
# 2             88.563240               188.268082                 0.0
# 3             90.001663               197.727295                 0.0
# 4             91.222733               193.704559                 0.0
#
#    Global Horizontal Radiation(W/m²)  Diffuse Horizontal Radiation(W/m²)  \
# 0                           2.672255                            1.103375
# 1                           2.703700                            1.152340
# 2                           3.013785                            1.566642
# 3                           3.421924                            1.707677
# 4                           3.292158                            1.746989
#
#           A         D  Station_4
# 0  0.000421 -0.000021   0.000400
# 1  0.000479 -0.000079   0.000400
# 2  0.000391  0.000142   0.000533
# 3  0.000256 -0.000190   0.000067
# 4  0.000396  0.000204   0.000600

# %%
test.head()
# Out:
#        Timestamp  Year  Month  Day  Hour  Minutes  Temperature(°C)  \
# 0  2019/1/1 0:00  2019      1    1     0        0        30.020723
# 1  2019/1/1 0:05  2019      1    1     0        5        29.958653
# 2  2019/1/1 0:10  2019      1    1     0       10        29.884491
# 3  2019/1/1 0:15  2019      1    1     0       15        29.831554
# 4  2019/1/1 0:20  2019      1    1     0       20        29.750330
#
#    Relative Humidity(%)  Wind Direction(Degrees)  Daily Rainfall(mm)  \
# 0             20.125513                32.213470                 0.0
# 1             20.040049                32.158791                 0.0
# 2             20.013313                32.155808                 0.0
# 3             20.068233                32.178555                 0.0
# 4             20.086567                32.166214                 0.0
#
#    Global Horizontal Radiation(W/m²)  Diffuse Horizontal Radiation(W/m²)  \
# 0                           1.543787                            1.349848
# 1                           1.373370                            1.244123
# 2                           1.142953                            0.992849
# 3                           0.709036                            0.611533
# 4                           1.058623                            0.814599
#
#           A         D  Station_4
# 0  0.000500  0.000033   0.000533
# 1  0.000575 -0.000141   0.000433
# 2  0.000654  0.000213   0.000867
# 3  0.000776 -0.000009   0.000767
# 4  0.000650 -0.000117   0.000533

# %% [markdown]
# # keras模型训练

# %% [markdown]
# 准备数据

# %%
train.corr()
# Out:
#                                             Year         Month       Day  \
# Year                                1.000000e+00  9.967574e-04 -0.001594
# Month                               9.967574e-04  1.000000e+00  0.010155
# Day                                -1.594487e-03  1.015470e-02  1.000000
# Hour                                2.713749e-04  2.458302e-04  0.000266
# Minutes                            -1.800243e-05 -2.427567e-05 -0.000006
# Temperature(°C)                     3.969199e-02 -7.850768e-02  0.037173
# Relative Humidity(%)               -1.426237e-01 -6.752481e-02 -0.019835
# Wind Direction(Degrees)            -3.064219e-01 -4.331950e-02 -0.017119
# Daily Rainfall(mm)                 -1.490547e-02  2.441756e-02  0.027726
# Global Horizontal Radiation(W/m²)   3.332422e-02  8.510575e-03 -0.006611
# Diffuse Horizontal Radiation(W/m²) -4.247166e-02  1.946236e-02 -0.000819
# A                                   7.441120e-03 -9.459802e-03 -0.002857
# D                                  -9.112006e-10 -4.215409e-09 -0.000001
# Station_4                           7.421878e-03 -9.435340e-03 -0.002849
#
#                                         Hour   Minutes  Temperature(°C)  \
# Year                                0.000271 -0.000018         0.039692
# Month                               0.000246 -0.000024        -0.078508
# Day                                 0.000266 -0.000006         0.037173
# Hour                                1.000000 -0.000017         0.272605
# Minutes                            -0.000017  1.000000         0.000059
# Temperature(°C)                     0.272605  0.000059         1.000000
# Relative Humidity(%)               -0.297760 -0.000112        -0.473446
# Wind Direction(Degrees)            -0.040612 -0.000660         0.159687
# Daily Rainfall(mm)                  0.075225  0.003149         0.025735
# Global Horizontal Radiation(W/m²)   0.063334  0.000814         0.499530
# Diffuse Horizontal Radiation(W/m²)  0.070256 -0.001205         0.405993
# A                                   0.070909  0.000303         0.420495
# D                                   0.000032 -0.000455         0.000702
# Station_4                           0.070728  0.000270         0.419459
#
#                                     Relative Humidity(%)  \
# Year                                           -0.142624
# Month                                          -0.067525
# Day                                            -0.019835
# Hour                                           -0.297760
# Minutes                                        -0.000112
# Temperature(°C)                                -0.473446
# Relative Humidity(%)                            1.000000
# Wind Direction(Degrees)                         0.087882
# Daily Rainfall(mm)                              0.217534
# Global Horizontal Radiation(W/m²)              -0.409781
# Diffuse Horizontal Radiation(W/m²)             -0.178606
# A                                              -0.406159
# D                                               0.000391
# Station_4                                      -0.405080
#
#                                     Wind Direction(Degrees)  \
# Year                                              -0.306422
# Month                                             -0.043320
# Day                                               -0.017119
# Hour                                              -0.040612
# Minutes                                           -0.000660
# Temperature(°C)                                    0.159687
# Relative Humidity(%)                               0.087882
# Wind Direction(Degrees)                            1.000000
# Daily Rainfall(mm)                                 0.053352
# Global Horizontal Radiation(W/m²)                  0.002940
# Diffuse Horizontal Radiation(W/m²)                 0.043017
# A                                                 -0.035475
# D                                                 -0.000217
# Station_4                                         -0.035399
#
#                                     Daily Rainfall(mm)  \
# Year                                         -0.014905
# Month                                         0.024418
# Day                                           0.027726
# Hour                                          0.075225
# Minutes                                       0.003149
# Temperature(°C)                               0.025735
# Relative Humidity(%)                          0.217534
# Wind Direction(Degrees)                       0.053352
# Daily Rainfall(mm)                            1.000000
# Global Horizontal Radiation(W/m²)            -0.032898
# Diffuse Horizontal Radiation(W/m²)            0.077250
# A                                            -0.034257
# D                                             0.000024
# Station_4                                    -0.034166
#
#                                     Global Horizontal Radiation(W/m²)  \
# Year                                                         0.033324
# Month                                                        0.008511
# Day                                                         -0.006611
# Hour                                                         0.063334
# Minutes                                                      0.000814
# Temperature(°C)                                              0.499530
# Relative Humidity(%)                                        -0.409781
# Wind Direction(Degrees)                                      0.002940
# Daily Rainfall(mm)                                          -0.032898
# Global Horizontal Radiation(W/m²)                            1.000000
# Diffuse Horizontal Radiation(W/m²)                           0.561071
# A                                                            0.963878
# D                                                            0.064260
# Station_4                                                    0.966004
#
#                                     Diffuse Horizontal Radiation(W/m²)  \
# Year                                                         -0.042472
# Month                                                         0.019462
# Day                                                          -0.000819
# Hour                                                          0.070256
# Minutes                                                      -0.001205
# Temperature(°C)                                               0.405993
# Relative Humidity(%)                                         -0.178606
# Wind Direction(Degrees)                                       0.043017
# Daily Rainfall(mm)                                            0.077250
# Global Horizontal Radiation(W/m²)                             0.561071
# Diffuse Horizontal Radiation(W/m²)                            1.000000
# A                                                             0.531277
# D                                                             0.003056
# Station_4                                                     0.530123
#
#                                                A             D  Station_4
# Year                                7.441120e-03 -9.112006e-10   0.007422
# Month                              -9.459802e-03 -4.215409e-09  -0.009435
# Day                                -2.856680e-03 -1.268384e-06  -0.002849
# Hour                                7.090942e-02  3.211559e-05   0.070728
# Minutes                             3.030837e-04 -4.547013e-04   0.000270
# Temperature(°C)                     4.204955e-01  7.016949e-04   0.419459
# Relative Humidity(%)               -4.061589e-01  3.905191e-04  -0.405080
# Wind Direction(Degrees)            -3.547492e-02 -2.171849e-04  -0.035399
# Daily Rainfall(mm)                 -3.425659e-02  2.439599e-05  -0.034166
# Global Horizontal Radiation(W/m²)   9.638783e-01  6.426050e-02   0.966004
# Diffuse Horizontal Radiation(W/m²)  5.312771e-01  3.055767e-03   0.530123
# A                                   1.000000e+00  1.808278e-09   0.997414
# D                                   1.808278e-09  1.000000e+00   0.071870
# Station_4                           9.974140e-01  7.186976e-02   1.000000

# %%
train.columns
# Out:
# Index(['Timestamp', 'Year', 'Month', 'Day', 'Hour', 'Minutes',
#        'Temperature(°C)', 'Relative Humidity(%)', 'Wind Direction(Degrees)',
#        'Daily Rainfall(mm)', 'Global Horizontal Radiation(W/m²)',
#        'Diffuse Horizontal Radiation(W/m²)', 'A', 'D', 'Station_4'],
#       dtype='object')

# %%
# #去除 WD，WDR 特征
# train1=train[['Temperature(°C)', 'Relative Humidity(%)', 'Wind Direction(Degrees)',
#        'Daily Rainfall(mm)', 'Global Horizontal Radiation(W/m²)',
#        'Diffuse Horizontal Radiation(W/m²)', 'Station_4']]
# print("查看训练集\n",train1.head())
# test1=test[['Temperature(°C)', 'Relative Humidity(%)', 'Wind Direction(Degrees)',
#        'Daily Rainfall(mm)', 'Global Horizontal Radiation(W/m²)',
#        'Diffuse Horizontal Radiation(W/m²)', 'Station_4']]
# print("查看测试集\n",test.head())
train1=train.drop(columns=['Timestamp','Year'])
test1= test.drop(columns=['Timestamp','Year'])

# %%
print(train1.head())
print(test1.head())
# Out:
#    Month  Day  Hour  Minutes  Temperature(°C)  Relative Humidity(%)  \
# 0      1    1     0        0        17.176111             87.095665
# 1      1    1     0        5        17.133446             87.671669
# 2      1    1     0       10        17.084999             88.563240
# 3      1    1     0       15        16.955778             90.001663
# 4      1    1     0       20        16.854271             91.222733
#
#    Wind Direction(Degrees)  Daily Rainfall(mm)  \
# 0               186.941284                 0.0
# 1               191.876770                 0.0
# 2               188.268082                 0.0
# 3               197.727295                 0.0
# 4               193.704559                 0.0
#
#    Global Horizontal Radiation(W/m²)  Diffuse Horizontal Radiation(W/m²)  \
# 0                           2.672255                            1.103375
# 1                           2.703700                            1.152340
# 2                           3.013785                            1.566642
# 3                           3.421924                            1.707677
# 4                           3.292158                            1.746989
#
#           A         D  Station_4
# 0  0.000421 -0.000021   0.000400
# 1  0.000479 -0.000079   0.000400
# 2  0.000391  0.000142   0.000533
# 3  0.000256 -0.000190   0.000067
# 4  0.000396  0.000204   0.000600
#    Month  Day  Hour  Minutes  Temperature(°C)  Relative Humidity(%)  \
# 0      1    1     0        0        30.020723             20.125513
# 1      1    1     0        5        29.958653             20.040049
# 2      1    1     0       10        29.884491             20.013313
# 3      1    1     0       15        29.831554             20.068233
# 4      1    1     0       20        29.750330             20.086567
#
#    Wind Direction(Degrees)  Daily Rainfall(mm)  \
# 0                32.213470                 0.0
# 1                32.158791                 0.0
# 2                32.155808                 0.0
# 3                32.178555                 0.0
# 4                32.166214                 0.0
#
#    Global Horizontal Radiation(W/m²)  Diffuse Horizontal Radiation(W/m²)  \
# 0                           1.543787                            1.349848
# 1                           1.373370                            1.244123
# 2                           1.142953                            0.992849
# 3                           0.709036                            0.611533
# 4                           1.058623                            0.814599
#
#           A         D  Station_4
# 0  0.000500  0.000033   0.000533
# 1  0.000575 -0.000141   0.000433
# 2  0.000654  0.000213   0.000867
# 3  0.000776 -0.000009   0.000767
# 4  0.000650 -0.000117   0.000533

# %% [markdown]
# # 构建序列

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
#     n_vars = 1 if type(data) is list else data.shape[1]
    n_vars = list(data)
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('%s(t-%d)' % (j, i)) for j in n_vars]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('%s(t)' % (j) )for j in n_vars]
        else:
            names += [('%s(t+%d)' % (j, i)) for j in n_vars]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
train1 = series_to_supervised(train1,12,1)
test1 = series_to_supervised(test1,12,1)

# %%
# Timestamp =

# %%
train1.columns
# Out:
# Index(['Month(t-12)', 'Day(t-12)', 'Hour(t-12)', 'Minutes(t-12)',
#        'Temperature(°C)(t-12)', 'Relative Humidity(%)(t-12)',
#        'Wind Direction(Degrees)(t-12)', 'Daily Rainfall(mm)(t-12)',
#        'Global Horizontal Radiation(W/m²)(t-12)',
#        'Diffuse Horizontal Radiation(W/m²)(t-12)',
#        ...
#        'Minutes(t)', 'Temperature(°C)(t)', 'Relative Humidity(%)(t)',
#        'Wind Direction(Degrees)(t)', 'Daily Rainfall(mm)(t)',
#        'Global Horizontal Radiation(W/m²)(t)',
#        'Diffuse Horizontal Radiation(W/m²)(t)', 'A(t)', 'D(t)',
#        'Station_4(t)'],
#       dtype='object', length=169)

# %%
test1.columns
# Out:
# Index(['Month(t-12)', 'Day(t-12)', 'Hour(t-12)', 'Minutes(t-12)',
#        'Temperature(°C)(t-12)', 'Relative Humidity(%)(t-12)',
#        'Wind Direction(Degrees)(t-12)', 'Daily Rainfall(mm)(t-12)',
#        'Global Horizontal Radiation(W/m²)(t-12)',
#        'Diffuse Horizontal Radiation(W/m²)(t-12)',
#        ...
#        'Minutes(t)', 'Temperature(°C)(t)', 'Relative Humidity(%)(t)',
#        'Wind Direction(Degrees)(t)', 'Daily Rainfall(mm)(t)',
#        'Global Horizontal Radiation(W/m²)(t)',
#        'Diffuse Horizontal Radiation(W/m²)(t)', 'A(t)', 'D(t)',
#        'Station_4(t)'],
#       dtype='object', length=169)

# %%
train1.shape
# Out:
# (314831, 169)

# %%
train1.drop(train1.columns[13:train1.shape[1]-1],axis=1,inplace=True)
test1.drop(test1.columns[13:test1.shape[1]-1],axis=1,inplace=True)

# %%
train1.columns
# Out:
# Index(['Month(t-12)', 'Day(t-12)', 'Hour(t-12)', 'Minutes(t-12)',
#        'Temperature(°C)(t-12)', 'Relative Humidity(%)(t-12)',
#        'Wind Direction(Degrees)(t-12)', 'Daily Rainfall(mm)(t-12)',
#        'Global Horizontal Radiation(W/m²)(t-12)',
#        'Diffuse Horizontal Radiation(W/m²)(t-12)', 'A(t-12)', 'D(t-12)',
#        'Station_4(t-12)', 'Station_4(t)'],
#       dtype='object')

# %% [markdown]
# # 归一化数据

# %%
train1 = train1.values
train1 = train1.astype('float32')     # 将整型变为float
scaler = MinMaxScaler(feature_range=(0, 1)) # 数据处理，归一化至0~1之间
train1 = scaler.fit_transform(train1)

test1 = test1.values
test1 = test1.astype('float32')     # 将整型变为float
scaler = MinMaxScaler(feature_range=(0, 1)) # 数据处理，归一化至0~1之间
test1 = scaler.fit_transform(test1)

inds = np.arange(train1.shape[0])
train1_inds = inds[0:int(train1.shape[0]*0.8)]
eval1_inds = inds[int(train1.shape[0]*0.8):train1.shape[0]]


train_X, train_y = train1[train1_inds,:-1], train1[train1_inds,-1:]
eval_X,eval_y = train1[eval1_inds,:-1], train1[eval1_inds,-1:]
test_X, test_y = test1[:, :-1], test1[:,-1:]

# reshape input to be 3D [samples, timesteps, features]
train_Xl = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
eval_Xl = eval_X.reshape((eval_X.shape[0],1,eval_X.shape[1]))
test_Xl = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape,eval_X.shape,eval_y.shape, test_X.shape, test_y.shape)
print(train_Xl.shape, train_y.shape,eval_Xl.shape,eval_y.shape, test_Xl.shape, test_y.shape)
# Out:
# (251864, 13) (251864, 1) (62967, 13) (62967, 1) (102876, 13) (102876, 1)
# (251864, 1, 13) (251864, 1) (62967, 1, 13) (62967, 1) (102876, 1, 13) (102876, 1)

# %%
test_y
# Out:
# array([[0.00435867],
#        [0.00435867],
#        [0.00438782],
#        ...,
#        [0.00443155],
#        [0.00450444],
#        [0.00450444]], dtype=float32)

# %%
print(train1)
# Out:
# [[0.         0.         0.         ... 0.49061587 0.00402196 0.00404842]
#  [0.         0.         0.         ... 0.49060294 0.00402196 0.00398227]
#  [0.         0.         0.         ... 0.49065226 0.00404842 0.00394258]
#  ...
#  [1.         1.0000001  0.95652175 ... 0.49063426 0.00402196 0.0040815 ]
#  [1.         1.0000001  0.95652175 ... 0.49060145 0.00395582 0.00406165]
#  [1.         1.0000001  0.95652175 ... 0.49064147 0.00402196 0.00402196]]

# %%
print(train_X)
# Out:
# [[0.         0.         0.         ... 0.07830338 0.49061587 0.00402196]
#  [0.         0.         0.         ... 0.07831408 0.49060294 0.00402196]
#  [0.         0.         0.         ... 0.07829796 0.49065226 0.00404842]
#  ...
#  [0.36363637 0.8666667  0.17391305 ... 0.07821751 0.4906304  0.00394258]
#  [0.36363637 0.8666667  0.17391305 ... 0.07821773 0.4905705  0.00388966]
#  [0.36363637 0.8666667  0.17391305 ... 0.07823253 0.49061218 0.00394258]]

# %%
print(train_y)
# Out:
# [[0.00404842]
#  [0.00398227]
#  [0.00394258]
#  ...
#  [0.00396904]
#  [0.0039955 ]
#  [0.00416749]]

# %%
print(train_X.shape,train_y.shape,test_X.shape,test_y.shape)
# Out:
# (251864, 13) (251864, 1) (102876, 13) (102876, 1)

# %%
train_X.shape[1]
# Out:
# 13

# %% [markdown]
# # SVM model

# %%
# model=svm.SVR(C=1, cache_size=200, coef0=0.0, degree=5, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.0001, verbose=False)
# model.fit(train_X, train_y)

# %%
# #模型保存
# modelsvm = model
# joblib.dump(modelsvm, "../logs/modelsvm.m")

# %%
# #模型读取
# clf = joblib.load("train_model.m")
# clf.predit([0,0]) #此处test_X为特征集

# %%
# testPredictSVM=modelsvm.predict(test_X)
# print(testPredictSVM.shape())
# testPredictSVM=testPredictSVM[:, np.newaxis]
# print(testPredictSVM.shape())

# %% [markdown]
# # BP model

# %%
model=Sequential() #初始化模型
model.add(Dense(64,input_shape = (train_X.shape[1],),activation='sigmoid',init='uniform')) #添加一个隐含层，注：只是第一个隐含层需指定input_dim
model.add(Dense(1,activation='sigmoid')) #添加输出层
model.compile(loss='mean_absolute_error', optimizer='rmsprop', metrics=['mae'])  # 编译，指定目标函数与优化方法
# model4.fit(train_X,train_y ) # 模型训练
history=model.fit(x = train_X,y = train_y, validation_data = (eval_X,eval_y), epochs=200, batch_size=1000)
model.evaluate(test_X,test_y) #模型测试
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(64, input_shape=(13,), activation="sigmoid", kernel_initializer="uniform")`
# Train on 251864 samples, validate on 62967 samples
# Epoch 1/200
# 251864/251864 [==============================] - 2s - loss: 0.1947 - mean_absolute_error: 0.1947 - val_loss: 0.1127 - val_mean_absolute_error: 0.1127
# Epoch 2/200
# 251864/251864 [==============================] - 2s - loss: 0.0817 - mean_absolute_error: 0.0817 - val_loss: 0.0693 - val_mean_absolute_error: 0.0693
# Epoch 3/200
# 251864/251864 [==============================] - 1s - loss: 0.0687 - mean_absolute_error: 0.0687 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616
# Epoch 4/200
# 251864/251864 [==============================] - 1s - loss: 0.0676 - mean_absolute_error: 0.0676 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625
# Epoch 5/200
# 251864/251864 [==============================] - 1s - loss: 0.0671 - mean_absolute_error: 0.0671 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609
# Epoch 6/200
# 251864/251864 [==============================] - 1s - loss: 0.0666 - mean_absolute_error: 0.0666 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613
# Epoch 7/200
# 251864/251864 [==============================] - 1s - loss: 0.0659 - mean_absolute_error: 0.0659 - val_loss: 0.0596 - val_mean_absolute_error: 0.0596
# Epoch 8/200
# 251864/251864 [==============================] - 2s - loss: 0.0649 - mean_absolute_error: 0.0649 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591
# Epoch 9/200
# 251864/251864 [==============================] - 1s - loss: 0.0634 - mean_absolute_error: 0.0634 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576
# Epoch 10/200
# 251864/251864 [==============================] - 2s - loss: 0.0612 - mean_absolute_error: 0.0612 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540
# Epoch 11/200
# 251864/251864 [==============================] - 2s - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511
# Epoch 12/200
# 251864/251864 [==============================] - 2s - loss: 0.0552 - mean_absolute_error: 0.0552 - val_loss: 0.0480 - val_mean_absolute_error: 0.0480
# Epoch 13/200
# 251864/251864 [==============================] - 2s - loss: 0.0516 - mean_absolute_error: 0.0516 - val_loss: 0.0442 - val_mean_absolute_error: 0.0442
# Epoch 14/200
# 251864/251864 [==============================] - ETA: 0s - loss: 0.0481 - mean_absolute_error: 0.048 - 2s - loss: 0.0480 - mean_absolute_error: 0.0480 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408
# Epoch 15/200
# 251864/251864 [==============================] - 1s - loss: 0.0450 - mean_absolute_error: 0.0450 - val_loss: 0.0375 - val_mean_absolute_error: 0.0375
# Epoch 16/200
# 251864/251864 [==============================] - 1s - loss: 0.0427 - mean_absolute_error: 0.0427 - val_loss: 0.0352 - val_mean_absolute_error: 0.0352
# Epoch 17/200
# 251864/251864 [==============================] - 1s - loss: 0.0408 - mean_absolute_error: 0.0408 - val_loss: 0.0330 - val_mean_absolute_error: 0.0330
# Epoch 18/200
# 251864/251864 [==============================] - 1s - loss: 0.0394 - mean_absolute_error: 0.0394 - val_loss: 0.0319 - val_mean_absolute_error: 0.0319
# Epoch 19/200
# 251864/251864 [==============================] - 1s - loss: 0.0383 - mean_absolute_error: 0.0383 - val_loss: 0.0304 - val_mean_absolute_error: 0.0304
# Epoch 20/200
# 251864/251864 [==============================] - 1s - loss: 0.0374 - mean_absolute_error: 0.0374 - val_loss: 0.0293 - val_mean_absolute_error: 0.0293
# Epoch 21/200
# 251864/251864 [==============================] - 1s - loss: 0.0366 - mean_absolute_error: 0.0366 - val_loss: 0.0290 - val_mean_absolute_error: 0.0290
# Epoch 22/200
# 251864/251864 [==============================] - 1s - loss: 0.0359 - mean_absolute_error: 0.0359 - val_loss: 0.0278 - val_mean_absolute_error: 0.0278
# Epoch 23/200
# 251864/251864 [==============================] - 1s - loss: 0.0354 - mean_absolute_error: 0.0354 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276
# Epoch 24/200
# 251864/251864 [==============================] - 1s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0266 - val_mean_absolute_error: 0.0266
# Epoch 25/200
# 251864/251864 [==============================] - 1s - loss: 0.0344 - mean_absolute_error: 0.0344 - val_loss: 0.0261 - val_mean_absolute_error: 0.0261
# Epoch 26/200
# 251864/251864 [==============================] - 1s - loss: 0.0340 - mean_absolute_error: 0.0340 - val_loss: 0.0257 - val_mean_absolute_error: 0.0257
# Epoch 27/200
# 251864/251864 [==============================] - 1s - loss: 0.0336 - mean_absolute_error: 0.0336 - val_loss: 0.0254 - val_mean_absolute_error: 0.0254
# Epoch 28/200
# 251864/251864 [==============================] - 1s - loss: 0.0332 - mean_absolute_error: 0.0332 - val_loss: 0.0253 - val_mean_absolute_error: 0.0253
# Epoch 29/200
# 251864/251864 [==============================] - 1s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0250 - val_mean_absolute_error: 0.0250
# Epoch 30/200
# 251864/251864 [==============================] - 1s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0247 - val_mean_absolute_error: 0.0247
# Epoch 31/200
# 251864/251864 [==============================] - 1s - loss: 0.0324 - mean_absolute_error: 0.0324 - val_loss: 0.0245 - val_mean_absolute_error: 0.0245
# Epoch 32/200
# 251864/251864 [==============================] - 1s - loss: 0.0322 - mean_absolute_error: 0.0322 - val_loss: 0.0244 - val_mean_absolute_error: 0.0244
# Epoch 33/200
# 251864/251864 [==============================] - 1s - loss: 0.0321 - mean_absolute_error: 0.0321 - val_loss: 0.0242 - val_mean_absolute_error: 0.0242
# Epoch 34/200
# 251864/251864 [==============================] - 1s - loss: 0.0319 - mean_absolute_error: 0.0319 - val_loss: 0.0240 - val_mean_absolute_error: 0.0240
# Epoch 35/200
# 251864/251864 [==============================] - 1s - loss: 0.0317 - mean_absolute_error: 0.0317 - val_loss: 0.0241 - val_mean_absolute_error: 0.0241
# Epoch 36/200
# 251864/251864 [==============================] - 1s - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238
# Epoch 37/200
# 251864/251864 [==============================] - 1s - loss: 0.0315 - mean_absolute_error: 0.0315 - val_loss: 0.0242 - val_mean_absolute_error: 0.0242
# Epoch 38/200
# 251864/251864 [==============================] - 1s - loss: 0.0314 - mean_absolute_error: 0.0314 - val_loss: 0.0241 - val_mean_absolute_error: 0.0241
# Epoch 39/200
# 251864/251864 [==============================] - 1s - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0235 - val_mean_absolute_error: 0.0235
# Epoch 40/200
# 251864/251864 [==============================] - 1s - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0247 - val_mean_absolute_error: 0.0247
# Epoch 41/200
# 251864/251864 [==============================] - 1s - loss: 0.0311 - mean_absolute_error: 0.0311 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238
# Epoch 42/200
# 251864/251864 [==============================] - 1s - loss: 0.0310 - mean_absolute_error: 0.0310 - val_loss: 0.0239 - val_mean_absolute_error: 0.0239
# Epoch 43/200
# 251864/251864 [==============================] - 1s - loss: 0.0309 - mean_absolute_error: 0.0309 - val_loss: 0.0233 - val_mean_absolute_error: 0.0233
# Epoch 44/200
# 251864/251864 [==============================] - 1s - loss: 0.0308 - mean_absolute_error: 0.0308 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236
# Epoch 45/200
# 251864/251864 [==============================] - 1s - loss: 0.0308 - mean_absolute_error: 0.0308 - val_loss: 0.0235 - val_mean_absolute_error: 0.0235
# Epoch 46/200
# 251864/251864 [==============================] - 1s - loss: 0.0307 - mean_absolute_error: 0.0307 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234
# Epoch 47/200
# 251864/251864 [==============================] - 1s - loss: 0.0307 - mean_absolute_error: 0.0307 - val_loss: 0.0232 - val_mean_absolute_error: 0.0232
# Epoch 48/200
# 251864/251864 [==============================] - 1s - loss: 0.0306 - mean_absolute_error: 0.0306 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236
# Epoch 49/200
# 251864/251864 [==============================] - 1s - loss: 0.0306 - mean_absolute_error: 0.0306 - val_loss: 0.0239 - val_mean_absolute_error: 0.0239
# Epoch 50/200
# 251864/251864 [==============================] - 1s - loss: 0.0305 - mean_absolute_error: 0.0305 - val_loss: 0.0233 - val_mean_absolute_error: 0.0233
# Epoch 51/200
# 251864/251864 [==============================] - 1s - loss: 0.0305 - mean_absolute_error: 0.0305 - val_loss: 0.0247 - val_mean_absolute_error: 0.0247
# Epoch 52/200
# 251864/251864 [==============================] - 1s - loss: 0.0304 - mean_absolute_error: 0.0304 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234
# Epoch 53/200
# 251864/251864 [==============================] - 1s - loss: 0.0304 - mean_absolute_error: 0.0304 - val_loss: 0.0230 - val_mean_absolute_error: 0.0230
# Epoch 54/200
# 251864/251864 [==============================] - 1s - loss: 0.0304 - mean_absolute_error: 0.0304 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234
# Epoch 55/200
# 251864/251864 [==============================] - 1s - loss: 0.0303 - mean_absolute_error: 0.0303 - val_loss: 0.0232 - val_mean_absolute_error: 0.0232
# Epoch 56/200
# 251864/251864 [==============================] - 1s - loss: 0.0303 - mean_absolute_error: 0.0303 - val_loss: 0.0229 - val_mean_absolute_error: 0.0229
# Epoch 57/200
# 251864/251864 [==============================] - 1s - loss: 0.0302 - mean_absolute_error: 0.0302 - val_loss: 0.0231 - val_mean_absolute_error: 0.0231
# Epoch 58/200
# 251864/251864 [==============================] - 1s - loss: 0.0302 - mean_absolute_error: 0.0302 - val_loss: 0.0239 - val_mean_absolute_error: 0.0239
# Epoch 59/200
# 251864/251864 [==============================] - 1s - loss: 0.0302 - mean_absolute_error: 0.0302 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234
# Epoch 60/200
# 251864/251864 [==============================] - 1s - loss: 0.0301 - mean_absolute_error: 0.0301 - val_loss: 0.0229 - val_mean_absolute_error: 0.0229
# Epoch 61/200
# 251864/251864 [==============================] - 1s - loss: 0.0301 - mean_absolute_error: 0.0301 - val_loss: 0.0230 - val_mean_absolute_error: 0.0230
# Epoch 62/200
# 251864/251864 [==============================] - 1s - loss: 0.0301 - mean_absolute_error: 0.0301 - val_loss: 0.0229 - val_mean_absolute_error: 0.0229
# Epoch 63/200
# 251864/251864 [==============================] - 1s - loss: 0.0301 - mean_absolute_error: 0.0301 - val_loss: 0.0231 - val_mean_absolute_error: 0.0231
# Epoch 64/200
# 251864/251864 [==============================] - 1s - loss: 0.0300 - mean_absolute_error: 0.0300 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228
# Epoch 65/200
# 251864/251864 [==============================] - 1s - loss: 0.0300 - mean_absolute_error: 0.0300 - val_loss: 0.0231 - val_mean_absolute_error: 0.0231
# Epoch 66/200
# 251864/251864 [==============================] - 1s - loss: 0.0300 - mean_absolute_error: 0.0300 - val_loss: 0.0230 - val_mean_absolute_error: 0.0230
# Epoch 67/200
# 251864/251864 [==============================] - 1s - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0231 - val_mean_absolute_error: 0.0231
# Epoch 68/200
# 251864/251864 [==============================] - 1s - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237
# Epoch 69/200
# 251864/251864 [==============================] - 1s - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228
# Epoch 70/200
# 251864/251864 [==============================] - 1s - loss: 0.0298 - mean_absolute_error: 0.0298 - val_loss: 0.0227 - val_mean_absolute_error: 0.0227
# Epoch 71/200
# 251864/251864 [==============================] - 1s - loss: 0.0298 - mean_absolute_error: 0.0298 - val_loss: 0.0227 - val_mean_absolute_error: 0.0227
# Epoch 72/200
# 251864/251864 [==============================] - 1s - loss: 0.0298 - mean_absolute_error: 0.0298 - val_loss: 0.0229 - val_mean_absolute_error: 0.0229
# Epoch 73/200
# 251864/251864 [==============================] - 1s - loss: 0.0297 - mean_absolute_error: 0.0297 - val_loss: 0.0232 - val_mean_absolute_error: 0.0232
# Epoch 74/200
# 251864/251864 [==============================] - 1s - loss: 0.0297 - mean_absolute_error: 0.0297 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228
# Epoch 75/200
# 251864/251864 [==============================] - 1s - loss: 0.0297 - mean_absolute_error: 0.0297 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226
# Epoch 76/200
# 251864/251864 [==============================] - 1s - loss: 0.0297 - mean_absolute_error: 0.0297 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238
# Epoch 77/200
# 251864/251864 [==============================] - 1s - loss: 0.0296 - mean_absolute_error: 0.0296 - val_loss: 0.0225 - val_mean_absolute_error: 0.0225
# Epoch 78/200
# 251864/251864 [==============================] - 1s - loss: 0.0296 - mean_absolute_error: 0.0296 - val_loss: 0.0240 - val_mean_absolute_error: 0.0240
# Epoch 79/200
# 251864/251864 [==============================] - 1s - loss: 0.0296 - mean_absolute_error: 0.0296 - val_loss: 0.0229 - val_mean_absolute_error: 0.0229
# Epoch 80/200
# 251864/251864 [==============================] - 1s - loss: 0.0295 - mean_absolute_error: 0.0295 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234
# Epoch 81/200
# 251864/251864 [==============================] - 1s - loss: 0.0295 - mean_absolute_error: 0.0295 - val_loss: 0.0233 - val_mean_absolute_error: 0.0233
# Epoch 82/200
# 251864/251864 [==============================] - 1s - loss: 0.0295 - mean_absolute_error: 0.0295 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236
# Epoch 83/200
# 251864/251864 [==============================] - 2s - loss: 0.0295 - mean_absolute_error: 0.0295 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228
# Epoch 84/200
# 251864/251864 [==============================] - 1s - loss: 0.0294 - mean_absolute_error: 0.0294 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224
# Epoch 85/200
# 251864/251864 [==============================] - 1s - loss: 0.0294 - mean_absolute_error: 0.0294 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224
# Epoch 86/200
# 251864/251864 [==============================] - 1s - loss: 0.0294 - mean_absolute_error: 0.0294 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224
# Epoch 87/200
# 251864/251864 [==============================] - 1s - loss: 0.0293 - mean_absolute_error: 0.0293 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226
# Epoch 88/200
# 251864/251864 [==============================] - 1s - loss: 0.0293 - mean_absolute_error: 0.0293 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224
# Epoch 89/200
# 251864/251864 [==============================] - 1s - loss: 0.0293 - mean_absolute_error: 0.0293 - val_loss: 0.0223 - val_mean_absolute_error: 0.0223
# Epoch 90/200
# 251864/251864 [==============================] - 1s - loss: 0.0292 - mean_absolute_error: 0.0292 - val_loss: 0.0238 - val_mean_absolute_error: 0.0238
# Epoch 91/200
# 251864/251864 [==============================] - 1s - loss: 0.0292 - mean_absolute_error: 0.0292 - val_loss: 0.0235 - val_mean_absolute_error: 0.0235
# Epoch 92/200
# 251864/251864 [==============================] - 1s - loss: 0.0292 - mean_absolute_error: 0.0292 - val_loss: 0.0232 - val_mean_absolute_error: 0.0232
# Epoch 93/200
# 251864/251864 [==============================] - 1s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0222 - val_mean_absolute_error: 0.0222
# Epoch 94/200
# 251864/251864 [==============================] - 1s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0222 - val_mean_absolute_error: 0.0222
# Epoch 95/200
# 251864/251864 [==============================] - 1s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226
# Epoch 96/200
# 251864/251864 [==============================] - 1s - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0229 - val_mean_absolute_error: 0.0229
# Epoch 97/200
# 251864/251864 [==============================] - 1s - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236
# Epoch 98/200
# 251864/251864 [==============================] - 1s - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0240 - val_mean_absolute_error: 0.0240
# Epoch 99/200
# 251864/251864 [==============================] - 1s - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0227 - val_mean_absolute_error: 0.0227
# Epoch 100/200
# 251864/251864 [==============================] - 1s - loss: 0.0289 - mean_absolute_error: 0.0289 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234
# Epoch 101/200
# 251864/251864 [==============================] - 1s - loss: 0.0289 - mean_absolute_error: 0.0289 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 102/200
# 251864/251864 [==============================] - 1s - loss: 0.0289 - mean_absolute_error: 0.0289 - val_loss: 0.0221 - val_mean_absolute_error: 0.0221
# Epoch 103/200
# 251864/251864 [==============================] - 1s - loss: 0.0288 - mean_absolute_error: 0.0288 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 104/200
# 251864/251864 [==============================] - 1s - loss: 0.0288 - mean_absolute_error: 0.0288 - val_loss: 0.0222 - val_mean_absolute_error: 0.0222
# Epoch 105/200
# 251864/251864 [==============================] - 1s - loss: 0.0288 - mean_absolute_error: 0.0288 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 106/200
# 251864/251864 [==============================] - 1s - loss: 0.0287 - mean_absolute_error: 0.0287 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224
# Epoch 107/200
# 251864/251864 [==============================] - 1s - loss: 0.0287 - mean_absolute_error: 0.0287 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 108/200
# 251864/251864 [==============================] - 1s - loss: 0.0287 - mean_absolute_error: 0.0287 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 109/200
# 251864/251864 [==============================] - 1s - loss: 0.0286 - mean_absolute_error: 0.0286 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219
# Epoch 110/200
# 251864/251864 [==============================] - 1s - loss: 0.0286 - mean_absolute_error: 0.0286 - val_loss: 0.0222 - val_mean_absolute_error: 0.0222
# Epoch 111/200
# 251864/251864 [==============================] - 1s - loss: 0.0286 - mean_absolute_error: 0.0286 - val_loss: 0.0229 - val_mean_absolute_error: 0.0229
# Epoch 112/200
# 251864/251864 [==============================] - 1s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 113/200
# 251864/251864 [==============================] - 1s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219
# Epoch 114/200
# 251864/251864 [==============================] - 1s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 115/200
# 251864/251864 [==============================] - 1s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226
# Epoch 116/200
# 251864/251864 [==============================] - 1s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218
# Epoch 117/200
# 251864/251864 [==============================] - 1s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 118/200
# 251864/251864 [==============================] - 1s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218
# Epoch 119/200
# 251864/251864 [==============================] - 1s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218
# Epoch 120/200
# 251864/251864 [==============================] - 1s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219
# Epoch 121/200
# 251864/251864 [==============================] - 1s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 122/200
# 251864/251864 [==============================] - 1s - loss: 0.0282 - mean_absolute_error: 0.0282 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219
# Epoch 123/200
# 251864/251864 [==============================] - 1s - loss: 0.0282 - mean_absolute_error: 0.0282 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216
# Epoch 124/200
# 251864/251864 [==============================] - 1s - loss: 0.0282 - mean_absolute_error: 0.0282 - val_loss: 0.0223 - val_mean_absolute_error: 0.0223
# Epoch 125/200
# 251864/251864 [==============================] - 1s - loss: 0.0282 - mean_absolute_error: 0.0282 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224
# Epoch 126/200
# 251864/251864 [==============================] - 1s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0215 - val_mean_absolute_error: 0.0215
# Epoch 127/200
# 251864/251864 [==============================] - 1s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216
# Epoch 128/200
# 251864/251864 [==============================] - 1s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 129/200
# 251864/251864 [==============================] - 1s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0215 - val_mean_absolute_error: 0.0215
# Epoch 130/200
# 251864/251864 [==============================] - 1s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0226 - val_mean_absolute_error: 0.0226
# Epoch 131/200
# 251864/251864 [==============================] - 1s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0223 - val_mean_absolute_error: 0.0223
# Epoch 132/200
# 251864/251864 [==============================] - 1s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0215 - val_mean_absolute_error: 0.0215
# Epoch 133/200
# 251864/251864 [==============================] - 1s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224
# Epoch 134/200
# 251864/251864 [==============================] - 1s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214
# Epoch 135/200
# 251864/251864 [==============================] - 1s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0223 - val_mean_absolute_error: 0.0223
# Epoch 136/200
# 251864/251864 [==============================] - 1s - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213
# Epoch 137/200
# 251864/251864 [==============================] - 1s - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219
# Epoch 138/200
# 251864/251864 [==============================] - 1s - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213
# Epoch 139/200
# 251864/251864 [==============================] - 1s - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 140/200
# 251864/251864 [==============================] - 1s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214
# Epoch 141/200
# 251864/251864 [==============================] - 1s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 142/200
# 251864/251864 [==============================] - 1s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214
# Epoch 143/200
# 251864/251864 [==============================] - 1s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224
# Epoch 144/200
# 251864/251864 [==============================] - 1s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214
# Epoch 145/200
# 251864/251864 [==============================] - 1s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 146/200
# 251864/251864 [==============================] - 1s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216
# Epoch 147/200
# 251864/251864 [==============================] - 1s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 148/200
# 251864/251864 [==============================] - 1s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219
# Epoch 149/200
# 251864/251864 [==============================] - 1s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 150/200
# 251864/251864 [==============================] - 1s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0215 - val_mean_absolute_error: 0.0215
# Epoch 151/200
# 251864/251864 [==============================] - 1s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 152/200
# 251864/251864 [==============================] - 1s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218
# Epoch 153/200
# 251864/251864 [==============================] - 1s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 154/200
# 251864/251864 [==============================] - 1s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0227 - val_mean_absolute_error: 0.0227
# Epoch 155/200
# 251864/251864 [==============================] - 1s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214
# Epoch 156/200
# 251864/251864 [==============================] - 1s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213
# Epoch 157/200
# 251864/251864 [==============================] - 1s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213
# Epoch 158/200
# 251864/251864 [==============================] - 1s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214
# Epoch 159/200
# 251864/251864 [==============================] - 1s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210
# Epoch 160/200
# 251864/251864 [==============================] - 1s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216
# Epoch 161/200
# 251864/251864 [==============================] - 1s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219
# Epoch 162/200
# 251864/251864 [==============================] - 1s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214
# Epoch 163/200
# 251864/251864 [==============================] - 1s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216
# Epoch 164/200
# 251864/251864 [==============================] - 1s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210
# Epoch 165/200
# 251864/251864 [==============================] - 1s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 166/200
# 251864/251864 [==============================] - 1s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 167/200
# 251864/251864 [==============================] - 1s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210
# Epoch 168/200
# 251864/251864 [==============================] - 1s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 169/200
# 251864/251864 [==============================] - 1s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 170/200
# 251864/251864 [==============================] - 1s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 171/200
# 251864/251864 [==============================] - 1s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 172/200
# 251864/251864 [==============================] - 1s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 173/200
# 251864/251864 [==============================] - 1s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 174/200
# 251864/251864 [==============================] - 1s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216
# Epoch 175/200
# 251864/251864 [==============================] - 1s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208
# Epoch 176/200
# 251864/251864 [==============================] - 1s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208
# Epoch 177/200
# 251864/251864 [==============================] - 1s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208
# Epoch 178/200
# 251864/251864 [==============================] - 1s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0211 - val_mean_absolute_error: 0.0211
# Epoch 179/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210
# Epoch 180/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0211 - val_mean_absolute_error: 0.0211
# Epoch 181/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210
# Epoch 182/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 183/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 184/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208
# Epoch 185/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 186/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208
# Epoch 187/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 188/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 189/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218
# Epoch 190/200
# 251864/251864 [==============================] - 1s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 191/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 192/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0215 - val_mean_absolute_error: 0.0215
# Epoch 193/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213
# Epoch 194/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208
# Epoch 195/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 196/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0211 - val_mean_absolute_error: 0.0211
# Epoch 197/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208
# Epoch 198/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 199/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 200/200
# 251864/251864 [==============================] - 1s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208
# 102464/102876 [============================>.] - ETA: 0s
# [0.02732266691610714, 0.02732266691610714]

# %%
#模型保存
modelbp = model
modelbp.save('../logs/BP0702WPD.h5')

# %%
# #模型加载
# modelbp = load_model('../logs/modelbp.h5')

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='eval')
plt.legend()
plt.show()

# %% [markdown]
# # DNN model

# %%
model = Sequential()
model.add(Dense(units=64, input_shape = (train_X.shape[1],),activation='sigmoid',name='layer1',use_bias = False))
model.add(Dense(units=32,activation='sigmoid',name='layer2',use_bias = True))
model.add(Dense(units=16,name='layer3',activation='sigmoid',use_bias = True))
# model.add(Dense(units=8,name='layer4',activation='sigmoid',use_bias = True))
model.add(Dense(units=1,name='layer5',activation='sigmoid'))
model.compile(loss='mean_absolute_error',
              optimizer='rmsprop',
              metrics=['mae'])
history=model.fit(x = train_X,y = train_y, validation_data = (eval_X,eval_y), epochs=200, batch_size=1000)
############################################################################################################
# Out:
# Train on 251864 samples, validate on 62967 samples
# Epoch 1/200
# 251864/251864 [==============================] - 2s - loss: 0.2375 - mean_absolute_error: 0.2375 - val_loss: 0.1954 - val_mean_absolute_error: 0.1954
# Epoch 2/200
# 251864/251864 [==============================] - 2s - loss: 0.1546 - mean_absolute_error: 0.1546 - val_loss: 0.0759 - val_mean_absolute_error: 0.0759
# Epoch 3/200
# 251864/251864 [==============================] - 2s - loss: 0.0690 - mean_absolute_error: 0.0690 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578
# Epoch 4/200
# 251864/251864 [==============================] - 2s - loss: 0.0599 - mean_absolute_error: 0.0599 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533
# Epoch 5/200
# 251864/251864 [==============================] - 2s - loss: 0.0577 - mean_absolute_error: 0.0577 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495
# Epoch 6/200
# 251864/251864 [==============================] - 2s - loss: 0.0544 - mean_absolute_error: 0.0544 - val_loss: 0.0451 - val_mean_absolute_error: 0.0451
# Epoch 7/200
# 251864/251864 [==============================] - 2s - loss: 0.0496 - mean_absolute_error: 0.0496 - val_loss: 0.0452 - val_mean_absolute_error: 0.0452
# Epoch 8/200
# 251864/251864 [==============================] - 2s - loss: 0.0449 - mean_absolute_error: 0.0449 - val_loss: 0.0341 - val_mean_absolute_error: 0.0341
# Epoch 9/200
# 251864/251864 [==============================] - 2s - loss: 0.0410 - mean_absolute_error: 0.0410 - val_loss: 0.0311 - val_mean_absolute_error: 0.0311
# Epoch 10/200
# 251864/251864 [==============================] - 2s - loss: 0.0376 - mean_absolute_error: 0.0376 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270
# Epoch 11/200
# 251864/251864 [==============================] - 2s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0281 - val_mean_absolute_error: 0.0281
# Epoch 12/200
# 251864/251864 [==============================] - 2s - loss: 0.0337 - mean_absolute_error: 0.0337 - val_loss: 0.0246 - val_mean_absolute_error: 0.0246
# Epoch 13/200
# 251864/251864 [==============================] - 2s - loss: 0.0330 - mean_absolute_error: 0.0330 - val_loss: 0.0267 - val_mean_absolute_error: 0.0267
# Epoch 14/200
# 251864/251864 [==============================] - 2s - loss: 0.0325 - mean_absolute_error: 0.0325 - val_loss: 0.0239 - val_mean_absolute_error: 0.0239
# Epoch 15/200
# 251864/251864 [==============================] - 2s - loss: 0.0322 - mean_absolute_error: 0.0322 - val_loss: 0.0273 - val_mean_absolute_error: 0.0273
# Epoch 16/200
# 251864/251864 [==============================] - 2s - loss: 0.0319 - mean_absolute_error: 0.0319 - val_loss: 0.0249 - val_mean_absolute_error: 0.0249
# Epoch 17/200
# 251864/251864 [==============================] - 2s - loss: 0.0318 - mean_absolute_error: 0.0318 - val_loss: 0.0233 - val_mean_absolute_error: 0.0233
# Epoch 18/200
# 251864/251864 [==============================] - 2s - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0281 - val_mean_absolute_error: 0.0281
# Epoch 19/200
# 251864/251864 [==============================] - 2s - loss: 0.0314 - mean_absolute_error: 0.0314 - val_loss: 0.0249 - val_mean_absolute_error: 0.0249
# Epoch 20/200
# 251864/251864 [==============================] - 2s - loss: 0.0313 - mean_absolute_error: 0.0313 - val_loss: 0.0230 - val_mean_absolute_error: 0.0230
# Epoch 21/200
# 251864/251864 [==============================] - 2s - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0232 - val_mean_absolute_error: 0.0232
# Epoch 22/200
# 251864/251864 [==============================] - 2s - loss: 0.0311 - mean_absolute_error: 0.0311 - val_loss: 0.0247 - val_mean_absolute_error: 0.0247
# Epoch 23/200
# 251864/251864 [==============================] - 2s - loss: 0.0310 - mean_absolute_error: 0.0310 - val_loss: 0.0255 - val_mean_absolute_error: 0.0255
# Epoch 24/200
# 251864/251864 [==============================] - 2s - loss: 0.0309 - mean_absolute_error: 0.0309 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228
# Epoch 25/200
# 251864/251864 [==============================] - 2s - loss: 0.0308 - mean_absolute_error: 0.0308 - val_loss: 0.0253 - val_mean_absolute_error: 0.0253
# Epoch 26/200
# 251864/251864 [==============================] - 2s - loss: 0.0307 - mean_absolute_error: 0.0307 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272
# Epoch 27/200
# 251864/251864 [==============================] - 2s - loss: 0.0306 - mean_absolute_error: 0.0306 - val_loss: 0.0225 - val_mean_absolute_error: 0.0225
# Epoch 28/200
# 251864/251864 [==============================] - 2s - loss: 0.0306 - mean_absolute_error: 0.0306 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237
# Epoch 29/200
# 251864/251864 [==============================] - 2s - loss: 0.0305 - mean_absolute_error: 0.0305 - val_loss: 0.0233 - val_mean_absolute_error: 0.0233
# Epoch 30/200
# 251864/251864 [==============================] - 2s - loss: 0.0303 - mean_absolute_error: 0.0303 - val_loss: 0.0222 - val_mean_absolute_error: 0.0222
# Epoch 31/200
# 251864/251864 [==============================] - 2s - loss: 0.0302 - mean_absolute_error: 0.0302 - val_loss: 0.0222 - val_mean_absolute_error: 0.0222
# Epoch 32/200
# 251864/251864 [==============================] - 2s - loss: 0.0302 - mean_absolute_error: 0.0302 - val_loss: 0.0225 - val_mean_absolute_error: 0.0225
# Epoch 33/200
# 251864/251864 [==============================] - 2s - loss: 0.0301 - mean_absolute_error: 0.0301 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 34/200
# 251864/251864 [==============================] - 2s - loss: 0.0300 - mean_absolute_error: 0.0300 - val_loss: 0.0234 - val_mean_absolute_error: 0.0234
# Epoch 35/200
# 251864/251864 [==============================] - 2s - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0289 - val_mean_absolute_error: 0.0289
# Epoch 36/200
# 251864/251864 [==============================] - 2s - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0249 - val_mean_absolute_error: 0.0249
# Epoch 37/200
# 251864/251864 [==============================] - 2s - loss: 0.0297 - mean_absolute_error: 0.0297 - val_loss: 0.0237 - val_mean_absolute_error: 0.0237
# Epoch 38/200
# 251864/251864 [==============================] - 2s - loss: 0.0297 - mean_absolute_error: 0.0297 - val_loss: 0.0243 - val_mean_absolute_error: 0.0243
# Epoch 39/200
# 251864/251864 [==============================] - 2s - loss: 0.0296 - mean_absolute_error: 0.0296 - val_loss: 0.0263 - val_mean_absolute_error: 0.0263
# Epoch 40/200
# 251864/251864 [==============================] - 2s - loss: 0.0295 - mean_absolute_error: 0.0295 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 41/200
# 251864/251864 [==============================] - 2s - loss: 0.0295 - mean_absolute_error: 0.0295 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216
# Epoch 42/200
# 251864/251864 [==============================] - 2s - loss: 0.0294 - mean_absolute_error: 0.0294 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 43/200
# 251864/251864 [==============================] - 2s - loss: 0.0293 - mean_absolute_error: 0.0293 - val_loss: 0.0220 - val_mean_absolute_error: 0.0220
# Epoch 44/200
# 251864/251864 [==============================] - 2s - loss: 0.0292 - mean_absolute_error: 0.0292 - val_loss: 0.0235 - val_mean_absolute_error: 0.0235
# Epoch 45/200
# 251864/251864 [==============================] - 2s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218
# Epoch 46/200
# 251864/251864 [==============================] - 2s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0235 - val_mean_absolute_error: 0.0235
# Epoch 47/200
# 251864/251864 [==============================] - 2s - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0221 - val_mean_absolute_error: 0.0221
# Epoch 48/200
# 251864/251864 [==============================] - 2s - loss: 0.0289 - mean_absolute_error: 0.0289 - val_loss: 0.0216 - val_mean_absolute_error: 0.0216
# Epoch 49/200
# 251864/251864 [==============================] - 2s - loss: 0.0289 - mean_absolute_error: 0.0289 - val_loss: 0.0242 - val_mean_absolute_error: 0.0242
# Epoch 50/200
# 251864/251864 [==============================] - 2s - loss: 0.0288 - mean_absolute_error: 0.0288 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 51/200
# 251864/251864 [==============================] - 2s - loss: 0.0287 - mean_absolute_error: 0.0287 - val_loss: 0.0215 - val_mean_absolute_error: 0.0215
# Epoch 52/200
# 251864/251864 [==============================] - 2s - loss: 0.0287 - mean_absolute_error: 0.0287 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218
# Epoch 53/200
# 251864/251864 [==============================] - 2s - loss: 0.0286 - mean_absolute_error: 0.0286 - val_loss: 0.0228 - val_mean_absolute_error: 0.0228
# Epoch 54/200
# 251864/251864 [==============================] - 2s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0253 - val_mean_absolute_error: 0.0253
# Epoch 55/200
# 251864/251864 [==============================] - 2s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236
# Epoch 56/200
# 251864/251864 [==============================] - 2s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 57/200
# 251864/251864 [==============================] - 2s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0211 - val_mean_absolute_error: 0.0211
# Epoch 58/200
# 251864/251864 [==============================] - 2s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0230 - val_mean_absolute_error: 0.0230
# Epoch 59/200
# 251864/251864 [==============================] - 2s - loss: 0.0282 - mean_absolute_error: 0.0282 - val_loss: 0.0223 - val_mean_absolute_error: 0.0223
# Epoch 60/200
# 251864/251864 [==============================] - 2s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 61/200
# 251864/251864 [==============================] - 2s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0215 - val_mean_absolute_error: 0.0215
# Epoch 62/200
# 251864/251864 [==============================] - 2s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0222 - val_mean_absolute_error: 0.0222
# Epoch 63/200
# 251864/251864 [==============================] - 2s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 64/200
# 251864/251864 [==============================] - 2s - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0236 - val_mean_absolute_error: 0.0236
# Epoch 65/200
# 251864/251864 [==============================] - 2s - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 66/200
# 251864/251864 [==============================] - 2s - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0227 - val_mean_absolute_error: 0.0227
# Epoch 67/200
# 251864/251864 [==============================] - 2s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0211 - val_mean_absolute_error: 0.0211
# Epoch 68/200
# 251864/251864 [==============================] - 2s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0233 - val_mean_absolute_error: 0.0233
# Epoch 69/200
# 251864/251864 [==============================] - 2s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 70/200
# 251864/251864 [==============================] - 2s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 71/200
# 251864/251864 [==============================] - 2s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219
# Epoch 72/200
# 251864/251864 [==============================] - 2s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0217 - val_mean_absolute_error: 0.0217
# Epoch 73/200
# 251864/251864 [==============================] - 2s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0215 - val_mean_absolute_error: 0.0215
# Epoch 74/200
# 251864/251864 [==============================] - 2s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0224 - val_mean_absolute_error: 0.0224
# Epoch 75/200
# 251864/251864 [==============================] - 2s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 76/200
# 251864/251864 [==============================] - 2s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 77/200
# 251864/251864 [==============================] - 2s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0221 - val_mean_absolute_error: 0.0221
# Epoch 78/200
# 251864/251864 [==============================] - 2s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0204 - val_mean_absolute_error: 0.0204
# Epoch 79/200
# 251864/251864 [==============================] - 2s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0240 - val_mean_absolute_error: 0.0240
# Epoch 80/200
# 251864/251864 [==============================] - 2s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0205 - val_mean_absolute_error: 0.0205
# Epoch 81/200
# 251864/251864 [==============================] - 2s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0204 - val_mean_absolute_error: 0.0204
# Epoch 82/200
# 251864/251864 [==============================] - 2s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210
# Epoch 83/200
# 251864/251864 [==============================] - 2s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0202 - val_mean_absolute_error: 0.0202
# Epoch 84/200
# 251864/251864 [==============================] - 2s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201
# Epoch 85/200
# 251864/251864 [==============================] - 2s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 86/200
# 251864/251864 [==============================] - 2s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0205 - val_mean_absolute_error: 0.0205
# Epoch 87/200
# 251864/251864 [==============================] - 2s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0219 - val_mean_absolute_error: 0.0219
# Epoch 88/200
# 251864/251864 [==============================] - 2s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0200 - val_mean_absolute_error: 0.0200
# Epoch 89/200
# 251864/251864 [==============================] - 2s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 90/200
# 251864/251864 [==============================] - 2s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210
# Epoch 91/200
# 251864/251864 [==============================] - 2s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198
# Epoch 92/200
# 251864/251864 [==============================] - 2s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198
# Epoch 93/200
# 251864/251864 [==============================] - 2s - loss: 0.0267 - mean_absolute_error: 0.0267 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198
# Epoch 94/200
# 251864/251864 [==============================] - 2s - loss: 0.0267 - mean_absolute_error: 0.0267 - val_loss: 0.0200 - val_mean_absolute_error: 0.0200
# Epoch 95/200
# 251864/251864 [==============================] - 2s - loss: 0.0266 - mean_absolute_error: 0.0266 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198
# Epoch 96/200
# 251864/251864 [==============================] - 2s - loss: 0.0266 - mean_absolute_error: 0.0266 - val_loss: 0.0210 - val_mean_absolute_error: 0.0210
# Epoch 97/200
# 251864/251864 [==============================] - 2s - loss: 0.0266 - mean_absolute_error: 0.0266 - val_loss: 0.0195 - val_mean_absolute_error: 0.0195
# Epoch 98/200
# 251864/251864 [==============================] - 2s - loss: 0.0265 - mean_absolute_error: 0.0265 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 99/200
# 251864/251864 [==============================] - 2s - loss: 0.0265 - mean_absolute_error: 0.0265 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214
# Epoch 100/200
# 251864/251864 [==============================] - 2s - loss: 0.0264 - mean_absolute_error: 0.0264 - val_loss: 0.0199 - val_mean_absolute_error: 0.0199
# Epoch 101/200
# 251864/251864 [==============================] - 2s - loss: 0.0264 - mean_absolute_error: 0.0264 - val_loss: 0.0199 - val_mean_absolute_error: 0.0199
# Epoch 102/200
# 251864/251864 [==============================] - 2s - loss: 0.0264 - mean_absolute_error: 0.0264 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193
# Epoch 103/200
# 251864/251864 [==============================] - 2s - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0195 - val_mean_absolute_error: 0.0195
# Epoch 104/200
# 251864/251864 [==============================] - 2s - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208
# Epoch 105/200
# 251864/251864 [==============================] - 2s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0218 - val_mean_absolute_error: 0.0218
# Epoch 106/200
# 251864/251864 [==============================] - 2s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212
# Epoch 107/200
# 251864/251864 [==============================] - 2s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196
# Epoch 108/200
# 251864/251864 [==============================] - 2s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 109/200
# 251864/251864 [==============================] - 2s - loss: 0.0261 - mean_absolute_error: 0.0261 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 110/200
# 251864/251864 [==============================] - 2s - loss: 0.0261 - mean_absolute_error: 0.0261 - val_loss: 0.0214 - val_mean_absolute_error: 0.0214
# Epoch 111/200
# 251864/251864 [==============================] - 2s - loss: 0.0260 - mean_absolute_error: 0.0260 - val_loss: 0.0203 - val_mean_absolute_error: 0.0203
# Epoch 112/200
# 251864/251864 [==============================] - 2s - loss: 0.0260 - mean_absolute_error: 0.0260 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196
# Epoch 113/200
# 251864/251864 [==============================] - 2s - loss: 0.0260 - mean_absolute_error: 0.0260 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196
# Epoch 114/200
# 251864/251864 [==============================] - 2s - loss: 0.0260 - mean_absolute_error: 0.0260 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192
# Epoch 115/200
# 251864/251864 [==============================] - 2s - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0213 - val_mean_absolute_error: 0.0213
# Epoch 116/200
# 251864/251864 [==============================] - 2s - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192
# Epoch 117/200
# 251864/251864 [==============================] - 2s - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0195 - val_mean_absolute_error: 0.0195
# Epoch 118/200
# 251864/251864 [==============================] - 2s - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.0203 - val_mean_absolute_error: 0.0203
# Epoch 119/200
# 251864/251864 [==============================] - 2s - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 120/200
# 251864/251864 [==============================] - 2s - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193
# Epoch 121/200
# 251864/251864 [==============================] - 2s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0190 - val_mean_absolute_error: 0.0190
# Epoch 122/200
# 251864/251864 [==============================] - 2s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192
# Epoch 123/200
# 251864/251864 [==============================] - 2s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0191 - val_mean_absolute_error: 0.0191
# Epoch 124/200
# 251864/251864 [==============================] - 2s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201
# Epoch 125/200
# 251864/251864 [==============================] - 2s - loss: 0.0256 - mean_absolute_error: 0.0256 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188
# Epoch 126/200
# 251864/251864 [==============================] - 2s - loss: 0.0256 - mean_absolute_error: 0.0256 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201
# Epoch 127/200
# 251864/251864 [==============================] - 2s - loss: 0.0256 - mean_absolute_error: 0.0256 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 128/200
# 251864/251864 [==============================] - 2s - loss: 0.0256 - mean_absolute_error: 0.0256 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188
# Epoch 129/200
# 251864/251864 [==============================] - 2s - loss: 0.0256 - mean_absolute_error: 0.0256 - val_loss: 0.0195 - val_mean_absolute_error: 0.0195
# Epoch 130/200
# 251864/251864 [==============================] - 2s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0197 - val_mean_absolute_error: 0.0197
# Epoch 131/200
# 251864/251864 [==============================] - 2s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192
# Epoch 132/200
# 251864/251864 [==============================] - 2s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0190 - val_mean_absolute_error: 0.0190
# Epoch 133/200
# 251864/251864 [==============================] - 2s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186
# Epoch 134/200
# 251864/251864 [==============================] - 2s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 135/200
# 251864/251864 [==============================] - 2s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186
# Epoch 136/200
# 251864/251864 [==============================] - 2s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187
# Epoch 137/200
# 251864/251864 [==============================] - 2s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186
# Epoch 138/200
# 251864/251864 [==============================] - 2s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188
# Epoch 139/200
# 251864/251864 [==============================] - 2s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196
# Epoch 140/200
# 251864/251864 [==============================] - 2s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183
# Epoch 141/200
# 251864/251864 [==============================] - 2s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184
# Epoch 142/200
# 251864/251864 [==============================] - 2s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0185 - val_mean_absolute_error: 0.0185
# Epoch 143/200
# 251864/251864 [==============================] - 2s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0197 - val_mean_absolute_error: 0.0197
# Epoch 144/200
# 251864/251864 [==============================] - 2s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 145/200
# 251864/251864 [==============================] - 2s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188
# Epoch 146/200
# 251864/251864 [==============================] - 2s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0201 - val_mean_absolute_error: 0.0201
# Epoch 147/200
# 251864/251864 [==============================] - 2s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192
# Epoch 148/200
# 251864/251864 [==============================] - 2s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188
# Epoch 149/200
# 251864/251864 [==============================] - 2s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186
# Epoch 150/200
# 251864/251864 [==============================] - 2s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186
# Epoch 151/200
# 251864/251864 [==============================] - 2s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184
# Epoch 152/200
# 251864/251864 [==============================] - 2s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 153/200
# 251864/251864 [==============================] - 2s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188
# Epoch 154/200
# 251864/251864 [==============================] - 2s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183
# Epoch 155/200
# 251864/251864 [==============================] - 2s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186
# Epoch 156/200
# 251864/251864 [==============================] - 2s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183
# Epoch 157/200
# 251864/251864 [==============================] - 2s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184
# Epoch 158/200
# 251864/251864 [==============================] - 2s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198
# Epoch 159/200
# 251864/251864 [==============================] - 2s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182
# Epoch 160/200
# 251864/251864 [==============================] - 2s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 161/200
# 251864/251864 [==============================] - 2s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0198 - val_mean_absolute_error: 0.0198
# Epoch 162/200
# 251864/251864 [==============================] - 2s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0185 - val_mean_absolute_error: 0.0185
# Epoch 163/200
# 251864/251864 [==============================] - 2s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0195 - val_mean_absolute_error: 0.0195
# Epoch 164/200
# 251864/251864 [==============================] - 2s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0196 - val_mean_absolute_error: 0.0196
# Epoch 165/200
# 251864/251864 [==============================] - 2s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182
# Epoch 166/200
# 251864/251864 [==============================] - 2s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182
# Epoch 167/200
# 251864/251864 [==============================] - 2s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184
# Epoch 168/200
# 251864/251864 [==============================] - 2s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0190 - val_mean_absolute_error: 0.0190
# Epoch 169/200
# 251864/251864 [==============================] - 2s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 170/200
# 251864/251864 [==============================] - 2s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182
# Epoch 171/200
# 251864/251864 [==============================] - 2s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0193 - val_mean_absolute_error: 0.0193
# Epoch 172/200
# 251864/251864 [==============================] - 2s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181
# Epoch 173/200
# 251864/251864 [==============================] - 2s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186
# Epoch 174/200
# 251864/251864 [==============================] - 2s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184
# Epoch 175/200
# 251864/251864 [==============================] - 2s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0191 - val_mean_absolute_error: 0.0191
# Epoch 176/200
# 251864/251864 [==============================] - 2s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187
# Epoch 177/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0185 - val_mean_absolute_error: 0.0185
# Epoch 178/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188
# Epoch 179/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181
# Epoch 180/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180
# Epoch 181/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186
# Epoch 182/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0184 - val_mean_absolute_error: 0.0184
# Epoch 183/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183
# Epoch 184/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0189 - val_mean_absolute_error: 0.0189
# Epoch 185/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180
# Epoch 186/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0178 - val_mean_absolute_error: 0.0178
# Epoch 187/200
# 251864/251864 [==============================] - 2s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182
# Epoch 188/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0178 - val_mean_absolute_error: 0.0178
# Epoch 189/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180
# Epoch 190/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0180 - val_mean_absolute_error: 0.0180
# Epoch 191/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0194 - val_mean_absolute_error: 0.0194
# Epoch 192/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181
# Epoch 193/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186
# Epoch 194/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181
# Epoch 195/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181
# Epoch 196/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0187 - val_mean_absolute_error: 0.0187
# Epoch 197/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188
# Epoch 198/200
# 251864/251864 [==============================] - 2s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0182 - val_mean_absolute_error: 0.0182
# Epoch 199/200
# 251864/251864 [==============================] - 2s - loss: 0.0246 - mean_absolute_error: 0.0246 - val_loss: 0.0181 - val_mean_absolute_error: 0.0181
# Epoch 200/200
# 251864/251864 [==============================] - 2s - loss: 0.0246 - mean_absolute_error: 0.0246 - val_loss: 0.0183 - val_mean_absolute_error: 0.0183

# %%
########################################################################
# 绘制训练 & 验证的损失值
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('DNN loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#模型保存
modeldnn = model
modeldnn.save('../logs/DNN0702WPD.h5')

# %%
# #模型加载
# modeldnn = load_model('../logs/modeldnn.h5')

# %% [markdown]
# # LSTM model

# %%
# design network
model = Sequential()
# model.add(LSTM(64, input_shape=(train_Xl.shape[1], train_Xl.shape[2])))
# model.add(Dense(1))
model.add(LSTM(64, input_shape=(train_Xl.shape[1], train_Xl.shape[2]),return_sequences=True))
model.add(LSTM(32,return_sequences=True,use_bias = True))
model.add(LSTM(16,return_sequences=False,use_bias = True))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
# history = model.fit(train_Xl, train_y, epochs=5, batch_size = 64, validation_data=(eval_Xl, eval_y), verbose=2, shuffle=False)
history = model.fit(train_Xl, train_y, epochs=200, batch_size = 1000, validation_data=(eval_Xl, eval_y), verbose=2, shuffle=False)
# Out:
# Train on 251864 samples, validate on 62967 samples
# Epoch 1/200
# 7s - loss: 0.0972 - val_loss: 0.0691
# Epoch 2/200
# 6s - loss: 0.0646 - val_loss: 0.0606
# Epoch 3/200
# 6s - loss: 0.0582 - val_loss: 0.0593
# Epoch 4/200
# 6s - loss: 0.0524 - val_loss: 0.0463
# Epoch 5/200
# 6s - loss: 0.0485 - val_loss: 0.0419
# Epoch 6/200
# 6s - loss: 0.0439 - val_loss: 0.0368
# Epoch 7/200
# 6s - loss: 0.0412 - val_loss: 0.0331
# Epoch 8/200
# 6s - loss: 0.0393 - val_loss: 0.0328
# Epoch 9/200
# 6s - loss: 0.0382 - val_loss: 0.0312
# Epoch 10/200
# 6s - loss: 0.0368 - val_loss: 0.0305
# Epoch 11/200
# 6s - loss: 0.0356 - val_loss: 0.0288
# Epoch 12/200
# 6s - loss: 0.0338 - val_loss: 0.0271
# Epoch 13/200
# 6s - loss: 0.0334 - val_loss: 0.0275
# Epoch 14/200
# 6s - loss: 0.0338 - val_loss: 0.0279
# Epoch 15/200
# 6s - loss: 0.0329 - val_loss: 0.0254
# Epoch 16/200
# 6s - loss: 0.0330 - val_loss: 0.0313
# Epoch 17/200
# 6s - loss: 0.0335 - val_loss: 0.0283
# Epoch 18/200
# 6s - loss: 0.0320 - val_loss: 0.0254
# Epoch 19/200
# 6s - loss: 0.0325 - val_loss: 0.0260
# Epoch 20/200
# 6s - loss: 0.0322 - val_loss: 0.0243
# Epoch 21/200
# 6s - loss: 0.0318 - val_loss: 0.0263
# Epoch 22/200
# 6s - loss: 0.0318 - val_loss: 0.0251
# Epoch 23/200
# 6s - loss: 0.0312 - val_loss: 0.0263
# Epoch 24/200
# 6s - loss: 0.0315 - val_loss: 0.0263
# Epoch 25/200
# 6s - loss: 0.0311 - val_loss: 0.0249
# Epoch 26/200
# 6s - loss: 0.0314 - val_loss: 0.0246
# Epoch 27/200
# 6s - loss: 0.0309 - val_loss: 0.0265
# Epoch 28/200
# 6s - loss: 0.0312 - val_loss: 0.0249
# Epoch 29/200
# 6s - loss: 0.0305 - val_loss: 0.0234
# Epoch 30/200
# 6s - loss: 0.0303 - val_loss: 0.0240
# Epoch 31/200
# 6s - loss: 0.0302 - val_loss: 0.0233
# Epoch 32/200
# 6s - loss: 0.0296 - val_loss: 0.0235
# Epoch 33/200
# 6s - loss: 0.0301 - val_loss: 0.0231
# Epoch 34/200
# 6s - loss: 0.0299 - val_loss: 0.0230
# Epoch 35/200
# 6s - loss: 0.0299 - val_loss: 0.0236
# Epoch 36/200
# 6s - loss: 0.0292 - val_loss: 0.0232
# Epoch 37/200
# 6s - loss: 0.0293 - val_loss: 0.0228
# Epoch 38/200
# 6s - loss: 0.0290 - val_loss: 0.0220
# Epoch 39/200
# 6s - loss: 0.0290 - val_loss: 0.0222
# Epoch 40/200
# 6s - loss: 0.0289 - val_loss: 0.0228
# Epoch 41/200
# 6s - loss: 0.0290 - val_loss: 0.0233
# Epoch 42/200
# 6s - loss: 0.0292 - val_loss: 0.0234
# Epoch 43/200
# 6s - loss: 0.0286 - val_loss: 0.0243
# Epoch 44/200
# 6s - loss: 0.0289 - val_loss: 0.0221
# Epoch 45/200
# 6s - loss: 0.0285 - val_loss: 0.0231
# Epoch 46/200
# 6s - loss: 0.0282 - val_loss: 0.0211
# Epoch 47/200
# 6s - loss: 0.0283 - val_loss: 0.0220
# Epoch 48/200
# 6s - loss: 0.0284 - val_loss: 0.0239
# Epoch 49/200
# 6s - loss: 0.0286 - val_loss: 0.0230
# Epoch 50/200
# 6s - loss: 0.0285 - val_loss: 0.0221
# Epoch 51/200
# 6s - loss: 0.0282 - val_loss: 0.0225
# Epoch 52/200
# 6s - loss: 0.0283 - val_loss: 0.0223
# Epoch 53/200
# 6s - loss: 0.0277 - val_loss: 0.0212
# Epoch 54/200
# 6s - loss: 0.0278 - val_loss: 0.0223
# Epoch 55/200
# 6s - loss: 0.0277 - val_loss: 0.0212
# Epoch 56/200
# 6s - loss: 0.0276 - val_loss: 0.0212
# Epoch 57/200
# 6s - loss: 0.0276 - val_loss: 0.0214
# Epoch 58/200
# 6s - loss: 0.0279 - val_loss: 0.0263
# Epoch 59/200
# 6s - loss: 0.0278 - val_loss: 0.0265
# Epoch 60/200
# 6s - loss: 0.0274 - val_loss: 0.0234
# Epoch 61/200
# 6s - loss: 0.0274 - val_loss: 0.0233
# Epoch 62/200
# 6s - loss: 0.0272 - val_loss: 0.0219
# Epoch 63/200
# 6s - loss: 0.0270 - val_loss: 0.0217
# Epoch 64/200
# 6s - loss: 0.0272 - val_loss: 0.0224
# Epoch 65/200
# 6s - loss: 0.0273 - val_loss: 0.0229
# Epoch 66/200
# 6s - loss: 0.0270 - val_loss: 0.0226
# Epoch 67/200
# 6s - loss: 0.0267 - val_loss: 0.0219
# Epoch 68/200
# 6s - loss: 0.0268 - val_loss: 0.0228
# Epoch 69/200
# 6s - loss: 0.0270 - val_loss: 0.0221
# Epoch 70/200
# 6s - loss: 0.0268 - val_loss: 0.0222
# Epoch 71/200
# 6s - loss: 0.0267 - val_loss: 0.0222
# Epoch 72/200
# 6s - loss: 0.0266 - val_loss: 0.0221
# Epoch 73/200
# 6s - loss: 0.0265 - val_loss: 0.0220
# Epoch 74/200
# 6s - loss: 0.0263 - val_loss: 0.0223
# Epoch 75/200
# 6s - loss: 0.0263 - val_loss: 0.0222
# Epoch 76/200
# 6s - loss: 0.0263 - val_loss: 0.0219
# Epoch 77/200
# 6s - loss: 0.0261 - val_loss: 0.0220
# Epoch 78/200
# 6s - loss: 0.0261 - val_loss: 0.0221
# Epoch 79/200
# 6s - loss: 0.0261 - val_loss: 0.0224
# Epoch 80/200
# 6s - loss: 0.0260 - val_loss: 0.0225
# Epoch 81/200
# 6s - loss: 0.0258 - val_loss: 0.0224
# Epoch 82/200
# 6s - loss: 0.0258 - val_loss: 0.0223
# Epoch 83/200
# 6s - loss: 0.0257 - val_loss: 0.0224
# Epoch 84/200
# 6s - loss: 0.0257 - val_loss: 0.0223
# Epoch 85/200
# 6s - loss: 0.0256 - val_loss: 0.0221
# Epoch 86/200
# 6s - loss: 0.0255 - val_loss: 0.0221
# Epoch 87/200
# 6s - loss: 0.0254 - val_loss: 0.0222
# Epoch 88/200
# 6s - loss: 0.0254 - val_loss: 0.0223
# Epoch 89/200
# 6s - loss: 0.0254 - val_loss: 0.0221
# Epoch 90/200
# 6s - loss: 0.0254 - val_loss: 0.0221
# Epoch 91/200
# 6s - loss: 0.0254 - val_loss: 0.0219
# Epoch 92/200
# 6s - loss: 0.0254 - val_loss: 0.0219
# Epoch 93/200
# 6s - loss: 0.0252 - val_loss: 0.0219
# Epoch 94/200
# 6s - loss: 0.0252 - val_loss: 0.0221
# Epoch 95/200
# 6s - loss: 0.0251 - val_loss: 0.0218
# Epoch 96/200
# 6s - loss: 0.0251 - val_loss: 0.0219
# Epoch 97/200
# 6s - loss: 0.0250 - val_loss: 0.0223
# Epoch 98/200
# 6s - loss: 0.0250 - val_loss: 0.0227
# Epoch 99/200
# 6s - loss: 0.0249 - val_loss: 0.0228
# Epoch 100/200
# 6s - loss: 0.0248 - val_loss: 0.0230
# Epoch 101/200
# 6s - loss: 0.0247 - val_loss: 0.0223
# Epoch 102/200
# 6s - loss: 0.0247 - val_loss: 0.0235
# Epoch 103/200
# 6s - loss: 0.0247 - val_loss: 0.0226
# Epoch 104/200
# 6s - loss: 0.0245 - val_loss: 0.0226
# Epoch 105/200
# 6s - loss: 0.0245 - val_loss: 0.0227
# Epoch 106/200
# 6s - loss: 0.0245 - val_loss: 0.0227
# Epoch 107/200
# 6s - loss: 0.0244 - val_loss: 0.0225
# Epoch 108/200
# 6s - loss: 0.0244 - val_loss: 0.0228
# Epoch 109/200
# 6s - loss: 0.0245 - val_loss: 0.0225
# Epoch 110/200
# 6s - loss: 0.0244 - val_loss: 0.0225
# Epoch 111/200
# 6s - loss: 0.0246 - val_loss: 0.0229
# Epoch 112/200
# 6s - loss: 0.0246 - val_loss: 0.0228
# Epoch 113/200
# 6s - loss: 0.0245 - val_loss: 0.0228
# Epoch 114/200
# 6s - loss: 0.0245 - val_loss: 0.0228
# Epoch 115/200
# 6s - loss: 0.0245 - val_loss: 0.0228
# Epoch 116/200
# 7s - loss: 0.0244 - val_loss: 0.0230
# Epoch 117/200
# 6s - loss: 0.0244 - val_loss: 0.0227
# Epoch 118/200
# 6s - loss: 0.0243 - val_loss: 0.0229
# Epoch 119/200
# 6s - loss: 0.0244 - val_loss: 0.0228
# Epoch 120/200
# 6s - loss: 0.0243 - val_loss: 0.0229
# Epoch 121/200
# 6s - loss: 0.0243 - val_loss: 0.0229
# Epoch 122/200
# 6s - loss: 0.0243 - val_loss: 0.0229
# Epoch 123/200
# 6s - loss: 0.0243 - val_loss: 0.0228
# Epoch 124/200
# 6s - loss: 0.0242 - val_loss: 0.0229
# Epoch 125/200
# 6s - loss: 0.0242 - val_loss: 0.0229
# Epoch 126/200
# 6s - loss: 0.0242 - val_loss: 0.0230
# Epoch 127/200
# 6s - loss: 0.0242 - val_loss: 0.0232
# Epoch 128/200
# 6s - loss: 0.0242 - val_loss: 0.0233
# Epoch 129/200
# 6s - loss: 0.0242 - val_loss: 0.0234
# Epoch 130/200
# 6s - loss: 0.0242 - val_loss: 0.0235
# Epoch 131/200
# 6s - loss: 0.0242 - val_loss: 0.0235
# Epoch 132/200
# 6s - loss: 0.0242 - val_loss: 0.0235
# Epoch 133/200
# 6s - loss: 0.0243 - val_loss: 0.0235
# Epoch 134/200
# 6s - loss: 0.0242 - val_loss: 0.0232
# Epoch 135/200
# 6s - loss: 0.0242 - val_loss: 0.0233
# Epoch 136/200
# 6s - loss: 0.0241 - val_loss: 0.0232
# Epoch 137/200
# 6s - loss: 0.0242 - val_loss: 0.0232
# Epoch 138/200
# 6s - loss: 0.0242 - val_loss: 0.0233
# Epoch 139/200
# 6s - loss: 0.0243 - val_loss: 0.0234
# Epoch 140/200
# 6s - loss: 0.0242 - val_loss: 0.0236
# Epoch 141/200
# 6s - loss: 0.0242 - val_loss: 0.0236
# Epoch 142/200
# 6s - loss: 0.0243 - val_loss: 0.0237
# Epoch 143/200
# 6s - loss: 0.0243 - val_loss: 0.0237
# Epoch 144/200
# 6s - loss: 0.0243 - val_loss: 0.0236
# Epoch 145/200
# 6s - loss: 0.0242 - val_loss: 0.0238
# Epoch 146/200
# 6s - loss: 0.0242 - val_loss: 0.0238
# Epoch 147/200
# 6s - loss: 0.0242 - val_loss: 0.0240
# Epoch 148/200
# 6s - loss: 0.0242 - val_loss: 0.0240
# Epoch 149/200
# 6s - loss: 0.0242 - val_loss: 0.0242
# Epoch 150/200
# 6s - loss: 0.0242 - val_loss: 0.0239
# Epoch 151/200
# 6s - loss: 0.0242 - val_loss: 0.0242
# Epoch 152/200
# 6s - loss: 0.0243 - val_loss: 0.0237
# Epoch 153/200
# 6s - loss: 0.0242 - val_loss: 0.0243
# Epoch 154/200
# 6s - loss: 0.0242 - val_loss: 0.0244
# Epoch 155/200
# 6s - loss: 0.0242 - val_loss: 0.0245
# Epoch 156/200
# 6s - loss: 0.0242 - val_loss: 0.0244
# Epoch 157/200
# 6s - loss: 0.0242 - val_loss: 0.0243
# Epoch 158/200
# 6s - loss: 0.0242 - val_loss: 0.0245
# Epoch 159/200
# 6s - loss: 0.0242 - val_loss: 0.0245
# Epoch 160/200
# 6s - loss: 0.0242 - val_loss: 0.0244
# Epoch 161/200
# 6s - loss: 0.0242 - val_loss: 0.0245
# Epoch 162/200
# 6s - loss: 0.0242 - val_loss: 0.0244
# Epoch 163/200
# 6s - loss: 0.0242 - val_loss: 0.0244
# Epoch 164/200
# 6s - loss: 0.0242 - val_loss: 0.0243
# Epoch 165/200
# 6s - loss: 0.0242 - val_loss: 0.0243
# Epoch 166/200
# 6s - loss: 0.0242 - val_loss: 0.0243
# Epoch 167/200
# 6s - loss: 0.0242 - val_loss: 0.0242
# Epoch 168/200
# 6s - loss: 0.0243 - val_loss: 0.0242
# Epoch 169/200
# 6s - loss: 0.0243 - val_loss: 0.0240
# Epoch 170/200
# 6s - loss: 0.0243 - val_loss: 0.0245
# Epoch 171/200
# 6s - loss: 0.0243 - val_loss: 0.0245
# Epoch 172/200
# 6s - loss: 0.0244 - val_loss: 0.0246
# Epoch 173/200
# 6s - loss: 0.0244 - val_loss: 0.0246
# Epoch 174/200
# 6s - loss: 0.0243 - val_loss: 0.0248
# Epoch 175/200
# 6s - loss: 0.0243 - val_loss: 0.0244
# Epoch 176/200
# 6s - loss: 0.0244 - val_loss: 0.0248
# Epoch 177/200
# 6s - loss: 0.0243 - val_loss: 0.0245
# Epoch 178/200
# 6s - loss: 0.0243 - val_loss: 0.0244
# Epoch 179/200
# 6s - loss: 0.0243 - val_loss: 0.0243
# Epoch 180/200
# 6s - loss: 0.0243 - val_loss: 0.0242
# Epoch 181/200
# 6s - loss: 0.0243 - val_loss: 0.0241
# Epoch 182/200
# 6s - loss: 0.0243 - val_loss: 0.0240
# Epoch 183/200
# 6s - loss: 0.0243 - val_loss: 0.0244
# Epoch 184/200
# 6s - loss: 0.0242 - val_loss: 0.0238
# Epoch 185/200
# 6s - loss: 0.0243 - val_loss: 0.0238
# Epoch 186/200
# 6s - loss: 0.0242 - val_loss: 0.0237
# Epoch 187/200
# 6s - loss: 0.0242 - val_loss: 0.0237
# Epoch 188/200
# 6s - loss: 0.0242 - val_loss: 0.0236
# Epoch 189/200
# 6s - loss: 0.0242 - val_loss: 0.0237
# Epoch 190/200
# 6s - loss: 0.0242 - val_loss: 0.0236
# Epoch 191/200
# 6s - loss: 0.0241 - val_loss: 0.0237
# Epoch 192/200
# 6s - loss: 0.0241 - val_loss: 0.0235
# Epoch 193/200
# 6s - loss: 0.0241 - val_loss: 0.0236
# Epoch 194/200
# 6s - loss: 0.0241 - val_loss: 0.0234
# Epoch 195/200
# 6s - loss: 0.0240 - val_loss: 0.0237
# Epoch 196/200
# 6s - loss: 0.0240 - val_loss: 0.0235
# Epoch 197/200
# 6s - loss: 0.0240 - val_loss: 0.0234
# Epoch 198/200
# 6s - loss: 0.0240 - val_loss: 0.0235
# Epoch 199/200
# 6s - loss: 0.0240 - val_loss: 0.0234
# Epoch 200/200
# 6s - loss: 0.0240 - val_loss: 0.0233

# %%
#模型保存
modellstm = model
modellstm.save('../logs/LSTM0702WPD.h5')

# %%
# #模型加载
# modellstm = load_model('../logs/modellstm.h5')

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='eval')
plt.legend()
plt.show()

# %%
# def inv2(testPredictML,test_X,test_y):
#     # invert scaling for forecast
#     inv_testPredictML = concatenate((test_X[:,:],testPredictML), axis=1)
#     inv_testPredictML = scaler.inverse_transform(inv_testPredictML)
#     testPredictML = inv_testPredictML[:,-1:]
#     # invert scaling for actual
#     test_y = test_y.reshape((len(test_y), 1))
#     inv_test = concatenate((test_X[:,:],test_y), axis=1)
#     inv_test = scaler.inverse_transform(inv_test)
#     testReal = inv_test[:,-1:]
#     return testPredictML,testReal

# %%
def inv(testPredictML,test_X,test_y):
    # invert scaling for forecast
    inv_testPredictML = concatenate((test_X[:,:],testPredictML), axis=1)
    inv_testPredictML = scaler.inverse_transform(inv_testPredictML)
    testPredictML = inv_testPredictML[:,-1:]
    # invert scaling for actual
    test_y = test_y.reshape((len(test_y), 1))
    inv_test = concatenate((test_X[:,:],test_y), axis=1)
    inv_test = scaler.inverse_transform(inv_test)
    testReal = inv_test[:,-1:]
    return testPredictML,testReal,inv_test

# %%
# # make a prediction
# testPredictls1 = model1.predict(test_X)
# testPredictls2 = model2.predict(test_X)

# %%
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# testPredictls1,testReal = inv2(testPredictls1,test_X,test_y)
# testPredictls2,testReal = inv2(testPredictls2,test_X,test_y)

# %%
# # calculate RMSE
# rmse = sqrt(mean_squared_error(testReal, testPredictls1))
# print('Test RMSE: %.3f' % rmse)

# %%
# #真实值和预测值对比图
# plt.plot(testReal,label='Real')
# plt.plot(testPredictls1,label='ls1Predicition')
# plt.plot(testPredictls2,label='ls2Predicition')
# # plt.plot(testPredictM3,label='M3Predicition')

# plt.title('Prediction test')
# plt.ylabel('Power')
# plt.xlabel('Time')
# # plt.plot(y_rr_,label='rr')
# # plt.plot(y_lasso_,label='lasso')
# plt.legend()

# %% [markdown]
# # 结果对比

# %%
#反归一化##
def inv00(pred,A_year,A_X,A_y):
    ######训练集#######
    inv_pred = concatenate((A_year[:,:],A_X[:,:],pred), axis=1)
    inv_pred = scaler.inverse_transform(inv_pred)
    pred = inv_pred[:,-1:]
    ###### 训练集真实值######
    A_y = A_y.reshape((len(A_y), 1))
    inv_A = concatenate((A_year[:,:],A_X[:,:],A_y), axis=1)
    inv_A = scaler.inverse_transform(inv_A)
    AReal = inv_A[:,-1:]
    return pred,AReal,inv_A

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred - y_true) / y_true)) * 100

def smape(y_true, y_pred):
    return 2.0 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true))) * 100

# %% [markdown]
# # svm

# %%
# svm_pred = modelsvm.predict(test_X)
# svm_pred = svm_pred[:, np.newaxis]
# svm_pred,y_true,inv_test=inv(svm_pred,test_X,test_y)

# %%
# svm_mse = metrics.mean_squared_error(y_true, svm_pred)
# # svm_rmse = math.sqrt(mean_squared_error(y_true[:,0], svm_pred[:,0]))
# svm_rmse = math.sqrt(mean_squared_error(y_true, svm_pred))
# svm_mae = metrics.mean_absolute_error(y_true, svm_pred)
# svm_mape = mape(y_true, svm_pred)
# svm_smape = smape(y_true, svm_pred)

# %%
# print(svm_mse,svm_rmse,svm_mae,svm_mape,svm_smape)

# %% [markdown]
# # bp

# %%
bp_pred = modelbp.predict(test_X)
bp_pred,y_true,inv_test=inv(bp_pred,test_X,test_y)

bp_mse = metrics.mean_squared_error(y_true, bp_pred)
bp_rmse = math.sqrt(mean_squared_error(y_true[:,0], bp_pred[:,0]))
bp_mae = metrics.mean_absolute_error(y_true, bp_pred)
bp_mape = mape(y_true, bp_pred)
bp_smape = smape(y_true, bp_pred)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %%
print(bp_mse,bp_rmse,bp_mae,bp_mape,bp_smape)
# Out:
# 0.070346035 0.26522826972867497 0.124953836 inf 113.14452886581421

# %% [markdown]
# # dnn

# %%
dnn_pred = modeldnn.predict(test_X)
# dnn_pred,y_true,inv_test=inv(dnn_pred,test_year,test_X,test_y)
dnn_pred,y_true,inv_test=inv(dnn_pred,test_X,test_y)

dnn_mse = metrics.mean_squared_error(y_true, dnn_pred)
dnn_rmse = math.sqrt(mean_squared_error(y_true[:,0], dnn_pred[:,0]))
dnn_mae = metrics.mean_absolute_error(y_true, dnn_pred)
dnn_mape = mape(y_true, dnn_pred)
dnn_smape = smape(y_true, dnn_pred)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %%
print(dnn_mse,dnn_rmse,dnn_mae,dnn_mape,dnn_smape)
# Out:
# 0.05937483 0.24366951310510412 0.09955986 inf 112.60402202606201

# %% [markdown]
# # LSTM

# %%
# make a prediction
lstm_pred = modellstm.predict(test_Xl)
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
lstm_pred,y_true,inv_test=inv(lstm_pred,test_X,test_y)
lstm_mse = metrics.mean_squared_error(y_true, lstm_pred)
lstm_rmse = math.sqrt(mean_squared_error(y_true[:,0], lstm_pred[:,0]))
lstm_mae = metrics.mean_absolute_error(y_true, lstm_pred)
lstm_mape = mape(y_true, lstm_pred)
lstm_smape = smape(y_true, lstm_pred)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %%
print(lstm_mse,lstm_rmse,lstm_mae,lstm_mape,lstm_smape)
# Out:
# 0.07532915 0.2744615588370483 0.13583234 inf 114.44815397262573

# %% [markdown]
# # 评价指标

# %%
#评价指标
# evaluate = pd.DataFrame(columns=['Test','SVM','BP','DNN','LSTM'])
evaluate = pd.DataFrame(columns=['Test','BP','DNN','LSTM'])

# %%
evaluate['Test']=['MSE','RMSE','MAE','MAPE','SMAPE']
evaluate=evaluate.set_index('Test',drop=True)

# %%
# evaluate['SVM']=[svm_mse,svm_rmse,svm_mae,svm_mape ,svm_smape]
evaluate['BP']=[bp_mse,bp_rmse,bp_mae,bp_mape ,bp_smape]
evaluate['DNN']=[dnn_mse,dnn_rmse,dnn_mae,dnn_mape ,dnn_smape]
evaluate['LSTM']=[lstm_mse,lstm_rmse,lstm_mae,lstm_mape,lstm_smape]
evaluate
# Out:
#                BP         DNN        LSTM
# Test
# MSE      0.070346    0.059375    0.075329
# RMSE     0.265228    0.243670    0.274462
# MAE      0.124954    0.099560    0.135832
# MAPE          inf         inf         inf
# SMAPE  113.144529  112.604022  114.448154

# %% [markdown]
# # 保存预测结果并绘图

# %%
# # from pylab import *
# # mpl.rcParams['font.sans-serif'] = ['SimHei']
# #真实值和预测值对比图
# # plt.plot(y_true,'royalblue',label='Real')
# # plt.plot(svm_pred,'orange',label='SVM')
# plt.plot(y_true,'b',label='Real')
# plt.plot(svm_pred,'m',label='SVM')



# plt.title('Station 1')
# plt.ylabel('Power')
# plt.xlabel('Time')
# plt.legend()
# plt.savefig('../picture/SVM1.jpg')

# %%
#真实值和预测值对比图
# plt.plot(y_true,'royalblue',label='Real')
# plt.plot(bp_pred,'limegreen',label='BP')
plt.plot(y_true,'b',label='Real')
plt.plot(bp_pred,'g',label='BP')


plt.title('Station 1')
plt.ylabel('Power')
plt.xlabel('Time')
plt.legend()
plt.savefig('../picture/BP0702.jpg')

# %%
#真实值和预测值对比图
# plt.plot(y_true,'royalblue',label='Real')
# plt.plot(dnn_pred,'tomato',label='DNN')
plt.plot(y_true,'b',label='Real')
plt.plot(dnn_pred,'y',label='DNN')


plt.title('Station 1')
plt.ylabel('Power')
plt.xlabel('Time')
plt.legend()
plt.savefig('../picture/DNN0702.jpg')

# %%
#真实值和预测值对比图

# plt.plot(lstm_pred,'orchid',label='LSTM')
plt.plot(y_true,'b',label='Real')
plt.plot(lstm_pred,'r',label='LSTM')

plt.title('Station 1')
plt.ylabel('Power')
plt.xlabel('Time')
plt.legend()
plt.savefig('../picture/LSTM0702.jpg')

# %% [markdown]
# # 保存

# %%
#真实值和预测值对比图
plt.plot(y_true,'b',label='Real')
# plt.plot(svm_pred,'m',label='SVM')
plt.plot(bp_pred,'g',label='BP')
plt.plot(dnn_pred,'y',label='DNN')
plt.plot(lstm_pred,'r',label='LSTM')

plt.title('Station 1')
plt.ylabel('Power')
plt.xlabel('Time')
plt.legend()
plt.savefig('../picture/SVMLSTM1.jpg')

#训练集和测试集 预测结果保存
predict_ = pd.DataFrame(inv_test)
# predict_.columns = ['Year', 'Month', 'Day', 'Hour', 'Minutes', 'WTC', 'WRH', 'GHR', 'DHR',
#        'RGT', 'RDT', '1A Trina_power']
predict_.columns = ['Month(t-12)', 'Day(t-12)', 'Hour(t-12)', 'Minutes(t-12)',
       'Temperature(°C)(t-12)', 'Relative Humidity(%)(t-12)',
       'Wind Direction(Degrees)(t-12)', 'Daily Rainfall(mm)(t-12)',
       'Global Horizontal Radiation(W/m²)(t-12)',
       'Diffuse Horizontal Radiation(W/m²)(t-12)', 'A(t-12)', 'D(t-12)',
       'Station_4(t-12)', 'Station_4(t)']
# predict_['WPD_SVM'] = svm_pred
predict_['WPD_BP'] = bp_pred
predict_['WPD_DNN'] = dnn_pred
predict_['WPD_LSTM'] = lstm_pred
predict_.to_csv('../predict/WPD_Station_4_predict.csv',index=False)

# %% [markdown]
# 画出例如2020年1月20号的预测图

# %%
predict_.columns

# %%
# from scipy.interpolate import spline
predict_[['Month(t-1)', 'Day(t-1)', 'Hour(t-1)', 'Minutes(t-1)']] = predict_[['Month(t-1)', 'Day(t-1)', 'Hour(t-1)', 'Minutes(t-1)']].astype("int")

# Day0120 = predict_.loc[(predict_['Year'] == 2020) & (predict_['Month'] == ) & (predict_['Day'] == 20),:]
Day0120 = predict_.loc[(predict_['Month(t-1)'] == 2 ) & (predict_['Day(t-1)'] == 20),:]
#real_power_day.set_index('time', inplace=False)
Real=Day0120.set_index('Hour(t-1)', inplace=False)['1A Trina_power(t+1)']
svm_pr=Day0120.set_index('Hour(t-1)', inplace=False)['SVM']
bp_pr=Day0120.set_index('Hour(t-1)', inplace=False)['BP']
dnn_pr=Day0120.set_index('Hour(t-1)', inplace=False)['DNN']
lstm_pr=Day0120.set_index('Hour(t-1)', inplace=False)['LSTM']

fig = plt.figure()
plt.plot(Real,label='Real')
plt.plot(svm_pr,label='SVM')
plt.plot(bp_pr,label='BP')
plt.plot(dnn_pr,label='DNN')
plt.plot(lstm_pr,label='LSTM')

plt.title('Prediction 2020-2-20')
plt.ylabel('Power')
plt.xlabel('Time')
# plt.legend(['Train', 'Test'], loc='upper left')
plt.legend()
plt.savefig('../picture/2-20pred.jpg')
#ax = fig.add_subplot(1,1,1)
#ax.plot(real_power_day_)
# real_power_day_.plot()
#real_power_day_.set_axis(['00:15:00','06:15:00','12:15:00','18:15:00'])
#real_power_day_

# %% [markdown]
# # 2020

# %%
# from scipy.interpolate import spline
predict_[['Month(t-1)', 'Day(t-1)', 'Hour(t-1)', 'Minutes(t-1)']] = predict_[['Month(t-1)', 'Day(t-1)', 'Hour(t-1)', 'Minutes(t-1)']].astype("int")

# Day0120 = predict_.loc[(predict_['Year'] == 2020) & (predict_['Month'] == ) & (predict_['Day'] == 20),:]
Day0120 = predict_.loc[(predict_['Month(t-1)'] == 3 ) & (predict_['Day(t-1)'] == 25),:]
#real_power_day.set_index('time', inplace=False)
Real=Day0120.set_index('Hour(t-1)', inplace=False)['1A Trina_power(t+1)']
svm_pr=Day0120.set_index('Hour(t-1)', inplace=False)['SVM']
bp_pr=Day0120.set_index('Hour(t-1)', inplace=False)['BP']
dnn_pr=Day0120.set_index('Hour(t-1)', inplace=False)['DNN']
lstm_pr=Day0120.set_index('Hour(t-1)', inplace=False)['LSTM']

fig = plt.figure()
plt.plot(Real,label='Real')
plt.plot(svm_pr,label='SVM')
plt.plot(bp_pr,label='BP')
plt.plot(dnn_pr,label='DNN')
plt.plot(lstm_pr,label='LSTM')

plt.title('Prediction 2020-3-25')
plt.ylabel('Power')
plt.xlabel('Time')
# plt.legend(['Train', 'Test'], loc='upper left')
plt.legend()
plt.savefig('../picture/3-25pred.jpg')
#ax = fig.add_subplot(1,1,1)
#ax.plot(real_power_day_)
# real_power_day_.plot()
#real_power_day_.set_axis(['00:15:00','06:15:00','12:15:00','18:15:00'])
#real_power_day_
